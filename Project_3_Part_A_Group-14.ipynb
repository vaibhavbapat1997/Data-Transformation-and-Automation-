# %% [markdown]
# # Project 3: Data Transformation and Automation

# %% [markdown]
# For Part A, we need to scrape IMDB web page to find out top movies sorted by user votes. For each movie, we need to pull :
#
# movie_id
# rank
# title
# runtime
# year
# rating
# votes
#
# The URL of an page that include movies released between 2018 and 2020 sorted by number of votes is:
#
# https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc

# %%
"""
    Warning messages are typically issued in situations where it is useful to alert the user of some condition in a program, 
    where that condition (normally) doesn’t warrant raising an exception and terminating the program.
    Beautiful Soup is a library that makes it easy to scrape information from web pages
"""   
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
"""
The read_html(url) return the contents of an URL html file as a string.
"""
def read_html(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)
    content = response.content
    return content

# %%
# This function, read a number of movies from a url html string. The default value is 50

def read_m_from_html_string(url, num_of_m=50):
    
    print(url)
    
    with open('TopVoted_500_Movies_HTML.txt', 'r', encoding="utf8") as file:
        html_string = file.read()   # to read the hmtl file as a string
        # I have included the Movies 500 HTML String.txt file in the project folder. Please take a look.
    
    # create a soup object
    soup = BeautifulSoup(html_string, "html.parser")
      
    movie_list = soup.find('div', 'ipc-page-grid__item ipc-page-grid__item--span-2') 
    
    # this div contains all the listed movies in the requested html web page string.
    
    list_movies = [] # initialize the function return value, which is a list of movies. 
                     # This list will contains the scraped data transformed to a structured format.
    
    # Using count track the number of movies processed. now it's 0 - No movie has been processed yet.
    count = 0
    
    # each movie listed in a div with attribute value 'ipc-metadata-list-summary-item'.
    divs=  movie_list.find_all('li','ipc-metadata-list-summary-item') # To find all the listed movies in the page.
    for d in divs:
        dict_each_movie = {}  # initialize the movie dictionary to store the movie information.

        # Pulling the movie_id, here as provided as an example for the rest of the list extraction,a tag has attribute href 
        # and we are extracting the id [7:16] lying between the title link
        
        try:
            movie_id= d.find('a', 'ipc-title-link-wrapper').attrs['href']
            movie_id= movie_id[7:16]
            
        except:
            movie_id=""
        finally:
            dict_each_movie["movie_id"] = movie_id
            print("movie_id=",movie_id)
              
            
        # Pulling the rank, used h3 class and used text split(.) to separate the title from rank
        
        try:
            movie_rank= d.find('h3', 'ipc-title__text').text.split('.')
            movie_rank= movie_rank[0]
            
        except:
            movie_rank=""
        finally:
            dict_each_movie["movie_rank"] = movie_rank
            print("movie_rank=",movie_rank)     
        
        
        # Pulling the title, again extracted from h3 class, but this time used the text extraction starting the 3rd character
       
        try:
            movie_title= d.find('h3', 'ipc-title__text').text
            movie_title= movie_title[3:]
            
        except:
            movie_title=""
        finally:
            dict_each_movie["movie_title"] = movie_title
            print("movie_title=",movie_title)   
                
        
        # Pulling the runtime,used the div class as the span class only  yielded year, as year, runtime and rating category had same span class
        # so used div class and extracted the character 4th and onward that also made the rating category attached along the runtime, 
        # have used trim function later on the upcoming section of this notebook
            
        try:
            movie_runtime= d.find('div', 'sc-479faa3c-7 jXgjdT dli-title-metadata').text
            movie_runtime= movie_runtime[4:]
            
        except:
            movie_runtime=""
        finally:
            dict_each_movie["movie_runtime"] = movie_runtime
            print("movie_runtime=",movie_runtime) 
        
        
        
        # Pulling the year, used span class as all the year have 4 digits and it was easier to extract
    
        try:
            movie_year= d.find('span', 'sc-479faa3c-8 bNrEFi dli-title-metadata-item').text
            movie_year= movie_year[0:]
            
        except:
            movie_year=""
        finally:
            dict_each_movie["movie_year"] = movie_year
            print("movie_year=",movie_year)        
        
        
        # Pulling the rating the rating out of 10   

        try:
            movie_rating= d.find('span', 'ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating').text
            movie_rating= movie_rating[0:3]
            
        except:
            movie_rating=""
        finally:
            dict_each_movie["movie_rating"] = movie_rating
            print("movie_rating=",movie_rating)       
    

        # Pulling the votes, used the div class, and used 5th and onward character as it would help us exclude "votes"
        # have to remove the "," for changing the datatype later on
    
        try:
            movie_votes= d.find('div', 'sc-21df249b-0 jmcDPS').text
            movie_votes= movie_votes[5:]
            
        except:
            movie_votes=""
        finally:
            dict_each_movie["movie_votes"] = movie_votes
            print("movie_votes=",movie_votes) 
            
        
        list_movies.append(dict_each_movie)  # To add the movie information to the movies list.

        count +=1
        print('===============================')
        print()
        if count == num_of_m:
            break # to exit from the loop.

    return list_movies

# %% [markdown]
# ##  Call statement to scrap the TopVoted 500 movies

# %%
# Have received some letters attached after the runtime, will remove them later on 

url = "https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc"

Movies_list = read_m_from_html_string(url,500)  #to read the topVoted 500 movies
Movies_list
# Out:
# https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc
# movie_id= tt7286456
# movie_rank= 1
# movie_title= Joker
# movie_runtime= 2h 2mR
# movie_year= 2019
# movie_rating= 8.4
# movie_votes= 1,422,218
# ===============================
#
# movie_id= tt4154796
# movie_rank= 2
# movie_title= Avengers: Endgame
# movie_runtime= 3h 1mPG-13
# movie_year= 2019
# movie_rating= 8.4
# movie_votes= 1,227,564
# ===============================
#
# movie_id= tt4154756
# movie_rank= 3
# movie_title= Avengers: Infinity War
# movie_runtime= 2h 29mPG-13
# movie_year= 2018
# movie_rating= 8.4
# movie_votes= 1,167,536
# ===============================
#
# movie_id= tt6751668
# movie_rank= 4
# movie_title= Parasite
# movie_runtime= 2h 12mR
# movie_year= 2019
# movie_rating= 8.5
# movie_votes= 903,939
# ===============================
#
# movie_id= tt1825683
# movie_rank= 5
# movie_title= Black Panther
# movie_runtime= 2h 14mPG-13
# movie_year= 2018
# movie_rating= 7.3
# movie_votes= 820,837
# ===============================
#
# movie_id= tt7131622
# movie_rank= 6
# movie_title= Once Upon a Time in Hollywood
# movie_runtime= 2h 41mR
# movie_year= 2019
# movie_rating= 7.6
# movie_votes= 809,786
# ===============================
#
# movie_id= tt8946378
# movie_rank= 7
# movie_title= Knives Out
# movie_runtime= 2h 10mPG-13
# movie_year= 2019
# movie_rating= 7.9
# movie_votes= 747,547
# ===============================
#
# movie_id= tt8579674
# movie_rank= 8
# movie_title= 1917
# movie_runtime= 1h 59mR
# movie_year= 2019
# movie_rating= 8.2
# movie_votes= 650,257
# ===============================
#
# movie_id= tt4633694
# movie_rank= 9
# movie_title= Spider-Man: Into the Spider-Verse
# movie_runtime= 1h 57mPG
# movie_year= 2018
# movie_rating= 8.4
# movie_votes= 641,118
# ===============================
#
# movie_id= tt5463162
# movie_rank= 10
# movie_title=  Deadpool 2
# movie_runtime= 1h 59mR
# movie_year= 2018
# movie_rating= 7.6
# movie_votes= 624,815
# ===============================
#
# movie_id= tt4154664
# movie_rank= 11
# movie_title=  Captain Marvel
# movie_runtime= 2h 3mPG-13
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 597,379
# ===============================
#
# movie_id= tt1727824
# movie_rank= 12
# movie_title=  Bohemian Rhapsody
# movie_runtime= 2h 14mPG-13
# movie_year= 2018
# movie_rating= 7.9
# movie_votes= 574,079
# ===============================
#
# movie_id= tt6723592
# movie_rank= 13
# movie_title=  Tenet
# movie_runtime= 2h 30mPG-13
# movie_year= 2020
# movie_rating= 7.3
# movie_votes= 568,337
# ===============================
#
# movie_id= tt6644200
# movie_rank= 14
# movie_title=  A Quiet Place
# movie_runtime= 1h 30mPG-13
# movie_year= 2018
# movie_rating= 7.5
# movie_votes= 567,953
# ===============================
#
# movie_id= tt6966692
# movie_rank= 15
# movie_title=  Green Book
# movie_runtime= 2h 10mPG-13
# movie_year= 2018
# movie_rating= 8.2
# movie_votes= 542,702
# ===============================
#
# movie_id= tt6320628
# movie_rank= 16
# movie_title=  Spider-Man: Far from Home
# movie_runtime= 2h 9mPG-13
# movie_year= 2019
# movie_rating= 7.4
# movie_votes= 537,741
# ===============================
#
# movie_id= tt1270797
# movie_rank= 17
# movie_title=  Venom
# movie_runtime= 1h 52mPG-13
# movie_year= 2018
# movie_rating= 6.6
# movie_votes= 523,643
# ===============================
#
# movie_id= tt1477834
# movie_rank= 18
# movie_title=  Aquaman
# movie_runtime= 2h 23mPG-13
# movie_year= 2018
# movie_rating= 6.8
# movie_votes= 505,411
# ===============================
#
# movie_id= tt2527338
# movie_rank= 19
# movie_title=  Star Wars: Episode IX - The Rise of Skywalker
# movie_runtime= 2h 21mPG-13
# movie_year= 2019
# movie_rating= 6.4
# movie_votes= 480,882
# ===============================
#
# movie_id= tt1677720
# movie_rank= 20
# movie_title=  Ready Player One
# movie_runtime= 2h 20mPG-13
# movie_year= 2018
# movie_rating= 7.4
# movie_votes= 468,943
# ===============================
#
# movie_id= tt1950186
# movie_rank= 21
# movie_title=  Ford v Ferrari
# movie_runtime= 2h 32mPG-13
# movie_year= 2019
# movie_rating= 8.1
# movie_votes= 444,406
# ===============================
#
# movie_id= tt5095030
# movie_rank= 22
# movie_title=  Ant-Man and the Wasp
# movie_runtime= 1h 58mPG-13
# movie_year= 2018
# movie_rating= 7.0
# movie_votes= 438,666
# ===============================
#
# movie_id= tt2584384
# movie_rank= 23
# movie_title=  Jojo Rabbit
# movie_runtime= 1h 48mPG-13
# movie_year= 2019
# movie_rating= 7.9
# movie_votes= 426,395
# ===============================
#
# movie_id= tt1302006
# movie_rank= 24
# movie_title=  The Irishman
# movie_runtime= 3h 29mR
# movie_year= 2019
# movie_rating= 7.8
# movie_votes= 418,772
# ===============================
#
# movie_id= tt6146586
# movie_rank= 25
# movie_title=  John Wick: Chapter 3 - Parabellum
# movie_runtime= 2h 10mR
# movie_year= 2019
# movie_rating= 7.4
# movie_votes= 411,173
# ===============================
#
# movie_id= tt1517451
# movie_rank= 26
# movie_title=  A Star Is Born
# movie_runtime= 2h 16mR
# movie_year= 2018
# movie_rating= 7.6
# movie_votes= 408,433
# ===============================
#
# movie_id= tt8772262
# movie_rank= 27
# movie_title=  Midsommar
# movie_runtime= 2h 28mR
# movie_year= 2019
# movie_rating= 7.1
# movie_votes= 378,718
# ===============================
#
# movie_id= tt0448115
# movie_rank= 28
# movie_title=  Shazam!
# movie_runtime= 2h 12mPG-13
# movie_year= 2019
# movie_rating= 7.0
# movie_votes= 375,801
# ===============================
#
# movie_id= tt8367814
# movie_rank= 29
# movie_title=  The Gentlemen
# movie_runtime= 1h 53mR
# movie_year= 2019
# movie_rating= 7.8
# movie_votes= 375,607
# ===============================
#
# movie_id= tt2737304
# movie_rank= 30
# movie_title=  Bird Box
# movie_runtime= 2h 4mR
# movie_year= 2018
# movie_rating= 6.6
# movie_votes= 375,423
# ===============================
#
# movie_id= tt3778644
# movie_rank= 31
# movie_title=  Solo: A Star Wars Story
# movie_runtime= 2h 15mPG-13
# movie_year= 2018
# movie_rating= 6.9
# movie_votes= 370,847
# ===============================
#
# movie_id= tt4912910
# movie_rank= 32
# movie_title=  Mission: Impossible - Fallout
# movie_runtime= 2h 27mPG-13
# movie_year= 2018
# movie_rating= 7.7
# movie_votes= 368,539
# ===============================
#
# movie_id= tt2948372
# movie_rank= 33
# movie_title=  Soul
# movie_runtime= 1h 40mPG
# movie_year= 2020
# movie_rating= 8.0
# movie_votes= 362,437
# ===============================
#
# movie_id= tt7784604
# movie_rank= 34
# movie_title=  Hereditary
# movie_runtime= 2h 7mR
# movie_year= 2018
# movie_rating= 7.3
# movie_votes= 361,849
# ===============================
#
# movie_id= tt2798920
# movie_rank= 35
# movie_title=  Annihilation
# movie_runtime= 1h 55mR
# movie_year= 2018
# movie_rating= 6.8
# movie_votes= 351,797
# ===============================
#
# movie_id= tt4881806
# movie_rank= 36
# movie_title=  Jurassic World: Fallen Kingdom
# movie_runtime= 2h 8mPG-13
# movie_year= 2018
# movie_rating= 6.1
# movie_votes= 336,377
# ===============================
#
# movie_id= tt7653254
# movie_rank= 37
# movie_title=  Marriage Story
# movie_runtime= 2h 17mR
# movie_year= 2019
# movie_rating= 7.9
# movie_votes= 335,814
# ===============================
#
# movie_id= tt6857112
# movie_rank= 38
# movie_title=  Us
# movie_runtime= 1h 56mR
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 330,835
# ===============================
#
# movie_id= tt3606756
# movie_rank= 39
# movie_title=  Incredibles 2
# movie_runtime= 1h 58mPG
# movie_year= 2018
# movie_rating= 7.6
# movie_votes= 321,021
# ===============================
#
# movie_id= tt5727208
# movie_rank= 40
# movie_title=  Uncut Gems
# movie_runtime= 2h 15mR
# movie_year= 2019
# movie_rating= 7.4
# movie_votes= 307,604
# ===============================
#
# movie_id= tt4123430
# movie_rank= 41
# movie_title=  Fantastic Beasts: The Crimes of Grindelwald
# movie_runtime= 2h 14mPG-13
# movie_year= 2018
# movie_rating= 6.5
# movie_votes= 301,523
# ===============================
#
# movie_id= tt7349950
# movie_rank= 42
# movie_title=  It Chapter Two
# movie_runtime= 2h 49mR
# movie_year= 2019
# movie_rating= 6.5
# movie_votes= 292,974
# ===============================
#
# movie_id= tt0437086
# movie_rank= 43
# movie_title=  Alita: Battle Angel
# movie_runtime= 2h 2mPG-13
# movie_year= 2019
# movie_rating= 7.3
# movie_votes= 286,837
# ===============================
#
# movie_id= tt7126948
# movie_rank= 44
# movie_title=  Wonder Woman 1984
# movie_runtime= 2h 31mPG-13
# movie_year= 2020
# movie_rating= 5.4
# movie_votes= 286,182
# ===============================
#
# movie_id= tt6139732
# movie_rank= 45
# movie_title=  Aladdin
# movie_runtime= 2h 8mPG
# movie_year= 2019
# movie_rating= 6.9
# movie_votes= 284,021
# ===============================
#
# movie_id= tt7349662
# movie_rank= 46
# movie_title=  BlacKkKlansman
# movie_runtime= 2h 15mR
# movie_year= 2018
# movie_rating= 7.5
# movie_votes= 283,407
# ===============================
#
# movie_id= tt9243946
# movie_rank= 47
# movie_title=  El Camino: A Breaking Bad Movie
# movie_runtime= 2h 2mTV-MA
# movie_year= 2019
# movie_rating= 7.3
# movie_votes= 281,195
# ===============================
#
# movie_id= tt7975244
# movie_rank= 48
# movie_title=  Jumanji: The Next Level
# movie_runtime= 2h 3mPG-13
# movie_year= 2019
# movie_rating= 6.7
# movie_votes= 273,028
# ===============================
#
# movie_id= tt1979376
# movie_rank= 49
# movie_title=  Toy Story 4
# movie_runtime= 1h 40mG
# movie_year= 2019
# movie_rating= 7.7
# movie_votes= 271,780
# ===============================
#
# movie_id= tt8332922
# movie_rank= 50
# movie_title=  A Quiet Place Part II
# movie_runtime= 1h 37mPG-13
# movie_year= 2020
# movie_rating= 7.2
# movie_votes= 262,410
# ===============================
#
# movie_id= tt6105098
# movie_rank= 51
# movie_title=  The Lion King
# movie_runtime= 1h 58mPG
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 261,359
# ===============================
#
# movie_id= tt6823368
# movie_rank= 52
# movie_title=  Glass
# movie_runtime= 2h 9mPG-13
# movie_year= 2019
# movie_rating= 6.6
# movie_votes= 260,948
# ===============================
#
# movie_id= tt8228288
# movie_rank= 53
# movie_title=  The Platform
# movie_runtime= 1h 34mTV-MA
# movie_year= 2019
# movie_rating= 7.0
# movie_votes= 259,815
# ===============================
#
# movie_id= tt7713068
# movie_rank= 54
# movie_title=  Birds of Prey
# movie_runtime= 1h 49mR
# movie_year= 2020
# movie_rating= 6.1
# movie_votes= 258,344
# ===============================
#
# movie_id= tt2935510
# movie_rank= 55
# movie_title=  Ad Astra
# movie_runtime= 2h 3mPG-13
# movie_year= 2019
# movie_rating= 6.5
# movie_votes= 254,595
# ===============================
#
# movie_id= tt8936646
# movie_rank= 56
# movie_title=  Extraction
# movie_runtime= 1h 56mR
# movie_year= 2020
# movie_rating= 6.8
# movie_votes= 254,119
# ===============================
#
# movie_id= tt2704998
# movie_rank= 57
# movie_title=  Game Night
# movie_runtime= 1h 40mR
# movie_year= 2018
# movie_rating= 6.9
# movie_votes= 250,596
# ===============================
#
# movie_id= tt1051906
# movie_rank= 58
# movie_title=  The Invisible Man
# movie_runtime= 2h 4mR
# movie_year= 2020
# movie_rating= 7.1
# movie_votes= 247,395
# ===============================
#
# movie_id= tt7984734
# movie_rank= 59
# movie_title=  The Lighthouse
# movie_runtime= 1h 49mR
# movie_year= 2019
# movie_rating= 7.4
# movie_votes= 243,403
# ===============================
#
# movie_id= tt5164214
# movie_rank= 60
# movie_title=  Ocean's Eight
# movie_runtime= 1h 50mPG-13
# movie_year= 2018
# movie_rating= 6.3
# movie_votes= 236,258
# ===============================
#
# movie_id= tt3281548
# movie_rank= 61
# movie_title=  Little Women
# movie_runtime= 2h 15mPG
# movie_year= 2019
# movie_rating= 7.8
# movie_votes= 232,103
# ===============================
#
# movie_id= tt6806448
# movie_rank= 62
# movie_title=  Fast & Furious Presents: Hobbs & Shaw
# movie_runtime= 2h 17mPG-13
# movie_year= 2019
# movie_rating= 6.5
# movie_votes= 230,128
# ===============================
#
# movie_id= tt1365519
# movie_rank= 63
# movie_title=  Tomb Raider
# movie_runtime= 1h 59mPG-13
# movie_year= 2018
# movie_rating= 6.3
# movie_votes= 223,462
# ===============================
#
# movie_id= tt5083738
# movie_rank= 64
# movie_title=  The Favourite
# movie_runtime= 1h 59mR
# movie_year= 2018
# movie_rating= 7.5
# movie_votes= 214,791
# ===============================
#
# movie_id= tt5606664
# movie_rank= 65
# movie_title=  Doctor Sleep
# movie_runtime= 2h 32mR
# movie_year= 2019
# movie_rating= 7.3
# movie_votes= 212,551
# ===============================
#
# movie_id= tt7846844
# movie_rank= 66
# movie_title=  Enola Holmes
# movie_runtime= 2h 3mPG-13
# movie_year= 2020
# movie_rating= 6.6
# movie_votes= 211,859
# ===============================
#
# movie_id= tt4779682
# movie_rank= 67
# movie_title=  The Meg
# movie_runtime= 1h 53mPG-13
# movie_year= 2018
# movie_rating= 5.6
# movie_votes= 201,680
# ===============================
#
# movie_id= tt6499752
# movie_rank= 68
# movie_title=  Upgrade
# movie_runtime= 1h 40mR
# movie_year= 2018
# movie_rating= 7.5
# movie_votes= 200,511
# ===============================
#
# movie_id= tt6565702
# movie_rank= 69
# movie_title=  Dark Phoenix
# movie_runtime= 1h 53mPG-13
# movie_year= 2019
# movie_rating= 5.7
# movie_votes= 199,925
# ===============================
#
# movie_id= tt9620292
# movie_rank= 70
# movie_title=  Promising Young Woman
# movie_runtime= 1h 53mR
# movie_year= 2020
# movie_rating= 7.5
# movie_votes= 199,117
# ===============================
#
# movie_id= tt1213641
# movie_rank= 71
# movie_title=  First Man
# movie_runtime= 2h 21mPG-13
# movie_year= 2018
# movie_rating= 7.3
# movie_votes= 198,491
# ===============================
#
# movie_id= tt2873282
# movie_rank= 72
# movie_title=  Red Sparrow
# movie_runtime= 2h 20mR
# movie_year= 2018
# movie_rating= 6.6
# movie_votes= 197,493
# ===============================
#
# movie_id= tt3741700
# movie_rank= 73
# movie_title=  Godzilla: King of the Monsters
# movie_runtime= 2h 12mPG-13
# movie_year= 2019
# movie_rating= 6.0
# movie_votes= 196,829
# ===============================
#
# movie_id= tt1560220
# movie_rank= 74
# movie_title=  Zombieland: Double Tap
# movie_runtime= 1h 39mR
# movie_year= 2019
# movie_rating= 6.7
# movie_votes= 195,173
# ===============================
#
# movie_id= tt8106534
# movie_rank= 75
# movie_title=  6 Underground
# movie_runtime= 2h 8mR
# movie_year= 2019
# movie_rating= 6.1
# movie_votes= 191,690
# ===============================
#
# movie_id= tt6450804
# movie_rank= 76
# movie_title=  Terminator: Dark Fate
# movie_runtime= 2h 8mR
# movie_year= 2019
# movie_rating= 6.2
# movie_votes= 189,385
# ===============================
#
# movie_id= tt2066051
# movie_rank= 77
# movie_title=  Rocketman
# movie_runtime= 2h 1mR
# movie_year= 2019
# movie_rating= 7.3
# movie_votes= 189,183
# ===============================
#
# movie_id= tt1070874
# movie_rank= 78
# movie_title=  The Trial of the Chicago 7
# movie_runtime= 2h 9mR
# movie_year= 2020
# movie_rating= 7.7
# movie_votes= 189,092
# ===============================
#
# movie_id= tt4520988
# movie_rank= 79
# movie_title=  Frozen II
# movie_runtime= 1h 43mPG
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 188,083
# ===============================
#
# movie_id= tt3766354
# movie_rank= 80
# movie_title=  The Equalizer 2
# movie_runtime= 2h 1mR
# movie_year= 2018
# movie_rating= 6.7
# movie_votes= 186,029
# ===============================
#
# movie_id= tt5104604
# movie_rank= 81
# movie_title=  Isle of Dogs
# movie_runtime= 1h 41mPG-13
# movie_year= 2018
# movie_rating= 7.8
# movie_votes= 185,670
# ===============================
#
# movie_id= tt3104988
# movie_rank= 82
# movie_title=  Crazy Rich Asians
# movie_runtime= 2hPG-13
# movie_year= 2018
# movie_rating= 6.9
# movie_votes= 185,039
# ===============================
#
# movie_id= tt1028856
# movie_rank= 83
# movie_title=  Another Round
# movie_runtime= 1h 57mNot Rated
# movie_year= 2020
# movie_rating= 7.7
# movie_votes= 184,238
# ===============================
#
# movie_id= tt4701182
# movie_rank= 84
# movie_title=  Bumblebee
# movie_runtime= 1h 54mPG-13
# movie_year= 2018
# movie_rating= 6.7
# movie_votes= 183,669
# ===============================
#
# movie_id= tt1027238
# movie_rank= 85
# movie_title=  The Father
# movie_runtime= 1h 37mPG-13
# movie_year= 2020
# movie_rating= 8.2
# movie_votes= 181,030
# ===============================
#
# movie_id= tt2231461
# movie_rank= 86
# movie_title=  Rampage
# movie_runtime= 1h 47mPG-13
# movie_year= 2018
# movie_rating= 6.1
# movie_votes= 180,984
# ===============================
#
# movie_id= tt7556122
# movie_rank= 87
# movie_title=  The Old Guard
# movie_runtime= 2h 5mR
# movie_year= 2020
# movie_rating= 6.7
# movie_votes= 178,994
# ===============================
#
# movie_id= tt5884052
# movie_rank= 88
# movie_title=  Pokémon: Detective Pikachu
# movie_runtime= 1h 44mPG
# movie_year= 2019
# movie_rating= 6.5
# movie_votes= 178,703
# ===============================
#
# movie_id= tt5848272
# movie_rank= 89
# movie_title=  Ralph Breaks the Internet
# movie_runtime= 1h 52mPG
# movie_year= 2018
# movie_rating= 7.0
# movie_votes= 176,980
# ===============================
#
# movie_id= tt7668870
# movie_rank= 90
# movie_title=  Searching
# movie_runtime= 1h 42mPG-13
# movie_year= 2018
# movie_rating= 7.6
# movie_votes= 176,831
# ===============================
#
# movie_id= tt9770150
# movie_rank= 91
# movie_title=  Nomadland
# movie_runtime= 1h 47mR
# movie_year= 2020
# movie_rating= 7.3
# movie_votes= 176,432
# ===============================
#
# movie_id= tt9484998
# movie_rank= 92
# movie_title=  Palm Springs
# movie_runtime= 1h 30mR
# movie_year= 2020
# movie_rating= 7.4
# movie_votes= 176,126
# ===============================
#
# movie_id= tt7798634
# movie_rank= 93
# movie_title=  Ready or Not
# movie_runtime= 1h 35mR
# movie_year= 2019
# movie_rating= 6.9
# movie_votes= 174,418
# ===============================
#
# movie_id= tt4729430
# movie_rank= 94
# movie_title=  Klaus
# movie_runtime= 1h 36mPG
# movie_year= 2019
# movie_rating= 8.2
# movie_votes= 174,273
# ===============================
#
# movie_id= tt1502397
# movie_rank= 95
# movie_title=  Bad Boys for Life
# movie_runtime= 2h 4mR
# movie_year= 2020
# movie_rating= 6.5
# movie_votes= 171,228
# ===============================
#
# movie_id= tt6155172
# movie_rank= 96
# movie_title=  Roma
# movie_runtime= 2h 15mR
# movie_year= 2018
# movie_rating= 7.7
# movie_votes= 166,837
# ===============================
#
# movie_id= tt1502407
# movie_rank= 97
# movie_title=  Halloween
# movie_runtime= 1h 46mR
# movie_year= 2018
# movie_rating= 6.5
# movie_votes= 166,377
# ===============================
#
# movie_id= tt5814060
# movie_rank= 98
# movie_title=  The Nun
# movie_runtime= 1h 36mR
# movie_year= 2018
# movie_rating= 5.3
# movie_votes= 165,487
# ===============================
#
# movie_id= tt7146812
# movie_rank= 99
# movie_title=  Onward
# movie_runtime= 1h 42mPG
# movie_year= 2020
# movie_rating= 7.4
# movie_votes= 164,363
# ===============================
#
# movie_id= tt6412452
# movie_rank= 100
# movie_title= . The Ballad of Buster Scruggs
# movie_runtime= 2h 13mR
# movie_year= 2018
# movie_rating= 7.3
# movie_votes= 162,660
# ===============================
#
# movie_id= tt1618434
# movie_rank= 101
# movie_title= . Murder Mystery
# movie_runtime= 1h 37mPG-13
# movie_year= 2019
# movie_rating= 6.0
# movie_votes= 162,527
# ===============================
#
# movie_id= tt8079248
# movie_rank= 102
# movie_title= . Yesterday
# movie_runtime= 1h 56mPG-13
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 162,400
# ===============================
#
# movie_id= tt5052474
# movie_rank= 103
# movie_title= . Sicario: Day of the Soldado
# movie_runtime= 2h 2mR
# movie_year= 2018
# movie_rating= 7.1
# movie_votes= 161,723
# ===============================
#
# movie_id= tt6628394
# movie_rank= 104
# movie_title= . Bad Times at the El Royale
# movie_runtime= 2h 21mR
# movie_year= 2018
# movie_rating= 7.1
# movie_votes= 160,769
# ===============================
#
# movie_id= tt7040874
# movie_rank= 105
# movie_title= . A Simple Favor
# movie_runtime= 1h 57mR
# movie_year= 2018
# movie_rating= 6.8
# movie_votes= 158,807
# ===============================
#
# movie_id= tt6266538
# movie_rank= 106
# movie_title= . Vice
# movie_runtime= 2h 12mR
# movie_year= 2018
# movie_rating= 7.2
# movie_votes= 158,256
# ===============================
#
# movie_id= tt4566758
# movie_rank= 107
# movie_title= . Mulan
# movie_runtime= 1h 55mPG-13
# movie_year= 2020
# movie_rating= 5.8
# movie_votes= 156,572
# ===============================
#
# movie_id= tt4500922
# movie_rank= 108
# movie_title= . Maze Runner: The Death Cure
# movie_runtime= 2h 23mPG-13
# movie_year= 2018
# movie_rating= 6.2
# movie_votes= 156,148
# ===============================
#
# movie_id= tt3794354
# movie_rank= 109
# movie_title= . Sonic the Hedgehog
# movie_runtime= 1h 39mPG
# movie_year= 2020
# movie_rating= 6.5
# movie_votes= 154,253
# ===============================
#
# movie_id= tt6343314
# movie_rank= 110
# movie_title= . Creed II
# movie_runtime= 2h 10mPG-13
# movie_year= 2018
# movie_rating= 7.1
# movie_votes= 151,484
# ===============================
#
# movie_id= tt1314396
# movie_rank= 111
# movie_title= . Borat Subsequent Moviefilm
# movie_runtime= 1h 35mR
# movie_year= 2020
# movie_rating= 6.6
# movie_votes= 149,914
# ===============================
#
# movie_id= tt7959026
# movie_rank= 112
# movie_title= . The Mule
# movie_runtime= 1h 56mR
# movie_year= 2018
# movie_rating= 7.0
# movie_votes= 148,511
# ===============================
#
# movie_id= tt7395114
# movie_rank= 113
# movie_title= . The Devil All the Time
# movie_runtime= 2h 18mR
# movie_year= 2020
# movie_rating= 7.1
# movie_votes= 148,065
# ===============================
#
# movie_id= tt7984766
# movie_rank= 114
# movie_title= . The King
# movie_runtime= 2h 20mR
# movie_year= 2019
# movie_rating= 7.3
# movie_votes= 145,183
# ===============================
#
# movie_id= tt2386490
# movie_rank= 115
# movie_title= . How to Train Your Dragon: The Hidden World
# movie_runtime= 1h 44mPG
# movie_year= 2019
# movie_rating= 7.4
# movie_votes= 144,640
# ===============================
#
# movie_id= tt5363618
# movie_rank= 116
# movie_title= . Sound of Metal
# movie_runtime= 2hR
# movie_year= 2019
# movie_rating= 7.7
# movie_votes= 144,292
# ===============================
#
# movie_id= tt2283336
# movie_rank= 117
# movie_title= . Men in Black: International
# movie_runtime= 1h 54mPG-13
# movie_year= 2019
# movie_rating= 5.6
# movie_votes= 143,562
# ===============================
#
# movie_id= tt2854926
# movie_rank= 118
# movie_title= . Tag
# movie_runtime= 1h 40mR
# movie_year= 2018
# movie_rating= 6.5
# movie_votes= 143,470
# ===============================
#
# movie_id= tt9893250
# movie_rank= 119
# movie_title= . I Care a Lot
# movie_runtime= 1h 58mR
# movie_year= 2020
# movie_rating= 6.4
# movie_votes= 141,697
# ===============================
#
# movie_id= tt1488606
# movie_rank= 120
# movie_title= . Triple Frontier
# movie_runtime= 2h 5mR
# movie_year= 2019
# movie_rating= 6.5
# movie_votes= 140,959
# ===============================
#
# movie_id= tt3829266
# movie_rank= 121
# movie_title= . The Predator
# movie_runtime= 1h 47mR
# movie_year= 2018
# movie_rating= 5.3
# movie_votes= 140,786
# ===============================
#
# movie_id= tt2222042
# movie_rank= 122
# movie_title= . Love and Monsters
# movie_runtime= 1h 49mPG-13
# movie_year= 2020
# movie_rating= 6.9
# movie_votes= 138,610
# ===============================
#
# movie_id= tt5886046
# movie_rank= 123
# movie_title= . Escape Room
# movie_runtime= 1h 39mPG-13
# movie_year= 2019
# movie_rating= 6.4
# movie_votes= 137,743
# ===============================
#
# movie_id= tt1571234
# movie_rank= 124
# movie_title= . Mortal Engines
# movie_runtime= 2h 8mPG-13
# movie_year= 2018
# movie_rating= 6.1
# movie_votes= 135,840
# ===============================
#
# movie_id= tt9495224
# movie_rank= 125
# movie_title= . Black Mirror: Bandersnatch
# movie_runtime= 1h 30mTV-MA
# movie_year= 2018
# movie_rating= 7.1
# movie_votes= 134,424
# ===============================
#
# movie_id= tt8110330
# movie_rank= 126
# movie_title= . Dil Bechara
# movie_runtime= 1h 41mNot Rated
# movie_year= 2020
# movie_rating= 8.3
# movie_votes= 133,875
# ===============================
#
# movie_id= tt5758778
# movie_rank= 127
# movie_title= . Skyscraper
# movie_runtime= 1h 42mPG-13
# movie_year= 2018
# movie_rating= 5.8
# movie_votes= 131,018
# ===============================
#
# movie_id= tt8404614
# movie_rank= 128
# movie_title= . The Two Popes
# movie_runtime= 2h 5mPG-13
# movie_year= 2019
# movie_rating= 7.6
# movie_votes= 130,684
# ===============================
#
# movie_id= tt7737786
# movie_rank= 129
# movie_title= . Greenland
# movie_runtime= 1h 59mPG-13
# movie_year= 2020
# movie_rating= 6.4
# movie_votes= 128,331
# ===============================
#
# movie_id= tt1489887
# movie_rank= 130
# movie_title= . Booksmart
# movie_runtime= 1h 42mR
# movie_year= 2019
# movie_rating= 7.1
# movie_votes= 128,024
# ===============================
#
# movie_id= tt2557478
# movie_rank= 131
# movie_title= . Pacific Rim: Uprising
# movie_runtime= 1h 51mPG-13
# movie_year= 2018
# movie_rating= 5.6
# movie_votes= 124,495
# ===============================
#
# movie_id= tt8244784
# movie_rank= 132
# movie_title= . The Hunt
# movie_runtime= 1h 30mR
# movie_year= 2020
# movie_rating= 6.5
# movie_votes= 124,384
# ===============================
#
# movie_id= tt6394270
# movie_rank= 133
# movie_title= . Bombshell
# movie_runtime= 1h 49mR
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 123,964
# ===============================
#
# movie_id= tt5164432
# movie_rank= 134
# movie_title= . Love, Simon
# movie_runtime= 1h 50mPG-13
# movie_year= 2018
# movie_rating= 7.5
# movie_votes= 122,819
# ===============================
#
# movie_id= tt1590193
# movie_rank= 135
# movie_title= . The Commuter
# movie_runtime= 1h 44mPG-13
# movie_year= 2018
# movie_rating= 6.3
# movie_votes= 122,803
# ===============================
#
# movie_id= tt1018951
# movie_rank= 136
# movie_title= . Soorarai Pottru
# movie_runtime= 2h 33mTV-MA
# movie_year= 2020
# movie_rating= 8.7
# movie_votes= 121,757
# ===============================
#
# movie_id= tt1259528
# movie_rank= 137
# movie_title= . Den of Thieves
# movie_runtime= 2h 20mR
# movie_year= 2018
# movie_rating= 7.0
# movie_votes= 120,572
# ===============================
#
# movie_id= tt3846674
# movie_rank= 138
# movie_title= . To All the Boys I've Loved Before
# movie_runtime= 1h 39mTV-14
# movie_year= 2018
# movie_rating= 7.0
# movie_votes= 119,878
# ===============================
#
# movie_id= tt1025100
# movie_rank= 139
# movie_title= . Gemini Man
# movie_runtime= 1h 57mPG-13
# movie_year= 2019
# movie_rating= 5.7
# movie_votes= 119,843
# ===============================
#
# movie_id= tt2139881
# movie_rank= 140
# movie_title= . Long Shot
# movie_runtime= 2h 5mR
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 119,017
# ===============================
#
# movie_id= tt7401588
# movie_rank= 141
# movie_title= . Instant Family
# movie_runtime= 1h 58mPG-13
# movie_year= 2018
# movie_rating= 7.3
# movie_votes= 116,032
# ===============================
#
# movie_id= tt4777008
# movie_rank= 142
# movie_title= . Maleficent: Mistress of Evil
# movie_runtime= 1h 59mPG
# movie_year= 2019
# movie_rating= 6.6
# movie_votes= 115,532
# ===============================
#
# movie_id= tt2548396
# movie_rank= 143
# movie_title= . The Cloverfield Paradox
# movie_runtime= 1h 42mPG-13
# movie_year= 2018
# movie_rating= 5.5
# movie_votes= 111,024
# ===============================
#
# movie_id= tt6048922
# movie_rank= 144
# movie_title= . Greyhound
# movie_runtime= 1h 31mPG-13
# movie_year= 2020
# movie_rating= 7.0
# movie_votes= 108,764
# ===============================
#
# movie_id= tt8503618
# movie_rank= 145
# movie_title= . Hamilton
# movie_runtime= 2h 40mPG-13
# movie_year= 2020
# movie_rating= 8.3
# movie_votes= 108,052
# ===============================
#
# movie_id= tt6189022
# movie_rank= 146
# movie_title= . Angel Has Fallen
# movie_runtime= 2h 1mR
# movie_year= 2019
# movie_rating= 6.4
# movie_votes= 107,137
# ===============================
#
# movie_id= tt1206885
# movie_rank= 147
# movie_title= . Rambo: Last Blood
# movie_runtime= 1h 29mR
# movie_year= 2019
# movie_rating= 6.1
# movie_votes= 106,885
# ===============================
#
# movie_id= tt5503686
# movie_rank= 148
# movie_title= . Hustlers
# movie_runtime= 1h 50mR
# movie_year= 2019
# movie_rating= 6.3
# movie_votes= 105,745
# ===============================
#
# movie_id= tt7752126
# movie_rank= 149
# movie_title= . Brightburn
# movie_runtime= 1h 30mR
# movie_year= 2019
# movie_rating= 6.1
# movie_votes= 105,439
# ===============================
#
# movie_id= tt6911608
# movie_rank= 150
# movie_title= . Mamma Mia! Here We Go Again
# movie_runtime= 1h 54mPG-13
# movie_year= 2018
# movie_rating= 6.6
# movie_votes= 105,015
# ===============================
#
# movie_id= tt4530422
# movie_rank= 151
# movie_title= . Overlord
# movie_runtime= 1h 50mR
# movie_year= 2018
# movie_rating= 6.6
# movie_votes= 104,896
# ===============================
#
# movie_id= tt8613070
# movie_rank= 152
# movie_title= . Portrait of a Lady on Fire
# movie_runtime= 2h 2mR
# movie_year= 2019
# movie_rating= 8.1
# movie_votes= 104,431
# ===============================
#
# movie_id= tt4218572
# movie_rank= 153
# movie_title= . Widows
# movie_runtime= 2h 9mR
# movie_year= 2018
# movie_rating= 6.8
# movie_votes= 102,660
# ===============================
#
# movie_id= tt8267604
# movie_rank= 154
# movie_title= . Capernaum
# movie_runtime= 2h 6mR
# movie_year= 2018
# movie_rating= 8.4
# movie_votes= 100,796
# ===============================
#
# movie_id= tt8580274
# movie_rank= 155
# movie_title= . Eurovision Song Contest: The Story of Fire Saga
# movie_runtime= 2h 3mPG-13
# movie_year= 2020
# movie_rating= 6.5
# movie_votes= 100,270
# ===============================
#
# movie_id= tt2481498
# movie_rank= 156
# movie_title= . Extremely Wicked, Shockingly Evil and Vile
# movie_runtime= 1h 50mR
# movie_year= 2019
# movie_rating= 6.7
# movie_votes= 100,175
# ===============================
#
# movie_id= tt8108198
# movie_rank= 157
# movie_title= . Andhadhun
# movie_runtime= 2h 19mNot Rated
# movie_year= 2018
# movie_rating= 8.2
# movie_votes= 99,830
# ===============================
#
# movie_id= tt1860242
# movie_rank= 158
# movie_title= . The Highwaymen
# movie_runtime= 2h 12mR
# movie_year= 2019
# movie_rating= 6.9
# movie_votes= 99,310
# ===============================
#
# movie_id= tt4364194
# movie_rank= 159
# movie_title= . The Peanut Butter Falcon
# movie_runtime= 1h 37mPG-13
# movie_year= 2019
# movie_rating= 7.6
# movie_votes= 98,992
# ===============================
#
# movie_id= tt6292852
# movie_rank= 160
# movie_title= . I Am Mother
# movie_runtime= 1h 53mTV-14
# movie_year= 2019
# movie_rating= 6.7
# movie_votes= 97,237
# ===============================
#
# movie_id= tt0837563
# movie_rank= 161
# movie_title= . Pet Sematary
# movie_runtime= 1h 40mR
# movie_year= 2019
# movie_rating= 5.7
# movie_votes= 97,070
# ===============================
#
# movie_id= tt9071322
# movie_rank= 162
# movie_title= . Dark Waters
# movie_runtime= 2h 6mPG-13
# movie_year= 2019
# movie_rating= 7.6
# movie_votes= 96,928
# ===============================
#
# movie_id= tt7939766
# movie_rank= 163
# movie_title= . I'm Thinking of Ending Things
# movie_runtime= 2h 14mR
# movie_year= 2020
# movie_rating= 6.6
# movie_votes= 96,858
# ===============================
#
# movie_id= tt4139588
# movie_rank= 164
# movie_title= . Polar
# movie_runtime= 1h 58mTV-MA
# movie_year= 2019
# movie_rating= 6.3
# movie_votes= 96,724
# ===============================
#
# movie_id= tt7886848
# movie_rank= 165
# movie_title= . Sadak 2
# movie_runtime= 2h 13mTV-MA
# movie_year= 2020
# movie_rating= 1.2
# movie_votes= 96,517
# ===============================
#
# movie_id= tt2274648
# movie_rank= 166
# movie_title= . Hellboy
# movie_runtime= 2hR
# movie_year= 2019
# movie_rating= 5.2
# movie_votes= 96,138
# ===============================
#
# movie_id= tt1088616
# movie_rank= 167
# movie_title= . 365 Days
# movie_runtime= 1h 54mTV-MA
# movie_year= 2020
# movie_rating= 3.3
# movie_votes= 96,084
# ===============================
#
# movie_id= tt7550000
# movie_rank= 168
# movie_title= . Project Power
# movie_runtime= 1h 53mR
# movie_year= 2020
# movie_rating= 6.0
# movie_votes= 95,606
# ===============================
#
# movie_id= tt8629748
# movie_rank= 169
# movie_title= . Spenser Confidential
# movie_runtime= 1h 51mR
# movie_year= 2020
# movie_rating= 6.2
# movie_votes= 95,361
# ===============================
#
# movie_id= tt3513548
# movie_rank= 170
# movie_title= . Richard Jewell
# movie_runtime= 2h 11mR
# movie_year= 2019
# movie_rating= 7.5
# movie_votes= 95,155
# ===============================
#
# movie_id= tt7838252
# movie_rank= 171
# movie_title= . K.G.F: Chapter 1
# movie_runtime= 2h 34mNot Rated
# movie_year= 2018
# movie_rating= 8.2
# movie_votes= 95,009
# ===============================
#
# movie_id= tt6878306
# movie_rank= 172
# movie_title= . News of the World
# movie_runtime= 1h 58mPG-13
# movie_year= 2020
# movie_rating= 6.8
# movie_votes= 93,724
# ===============================
#
# movie_id= tt5028340
# movie_rank= 173
# movie_title= . Mary Poppins Returns
# movie_runtime= 2h 10mPG
# movie_year= 2018
# movie_rating= 6.7
# movie_votes= 93,395
# ===============================
#
# movie_id= tt1226837
# movie_rank= 174
# movie_title= . Beautiful Boy
# movie_runtime= 2hR
# movie_year= 2018
# movie_rating= 7.4
# movie_votes= 92,783
# ===============================
#
# movie_id= tt6924650
# movie_rank= 175
# movie_title= . Midway
# movie_runtime= 2h 18mPG-13
# movie_year= 2019
# movie_rating= 6.7
# movie_votes= 92,301
# ===============================
#
# movie_id= tt1063345
# movie_rank= 176
# movie_title= . Minari
# movie_runtime= 1h 55mPG-13
# movie_year= 2020
# movie_rating= 7.4
# movie_votes= 91,987
# ===============================
#
# movie_id= tt8364368
# movie_rank= 177
# movie_title= . Crawl
# movie_runtime= 1h 27mR
# movie_year= 2019
# movie_rating= 6.1
# movie_votes= 91,964
# ===============================
#
# movie_id= tt8633478
# movie_rank= 178
# movie_title= . Run
# movie_runtime= 1h 30mPG-13
# movie_year= 2020
# movie_rating= 6.7
# movie_votes= 91,711
# ===============================
#
# movie_id= tt5774060
# movie_rank= 179
# movie_title= . Underwater
# movie_runtime= 1h 35mPG-13
# movie_year= 2020
# movie_rating= 5.9
# movie_votes= 91,474
# ===============================
#
# movie_id= tt3799232
# movie_rank= 180
# movie_title= . The Kissing Booth
# movie_runtime= 1h 45mTV-14
# movie_year= 2018
# movie_rating= 5.9
# movie_votes= 90,621
# ===============================
#
# movie_id= tt7456310
# movie_rank= 181
# movie_title= . Anna
# movie_runtime= 1h 58mR
# movie_year= 2019
# movie_rating= 6.6
# movie_votes= 90,487
# ===============================
#
# movie_id= tt1413492
# movie_rank= 182
# movie_title= . 12 Strong
# movie_runtime= 2h 10mR
# movie_year= 2018
# movie_rating= 6.5
# movie_votes= 89,720
# ===============================
#
# movie_id= tt1034415
# movie_rank= 183
# movie_title= . Suspiria
# movie_runtime= 2h 32mR
# movie_year= 2018
# movie_rating= 6.7
# movie_votes= 88,819
# ===============================
#
# movie_id= tt4332232
# movie_rank= 184
# movie_title= . Fractured
# movie_runtime= 1h 39mTV-MA
# movie_year= 2019
# movie_rating= 6.4
# movie_votes= 88,196
# ===============================
#
# movie_id= tt1146482
# movie_rank= 185
# movie_title= . The Social Dilemma
# movie_runtime= 1h 34mPG-13
# movie_year= 2020
# movie_rating= 7.6
# movie_votes= 87,849
# ===============================
#
# movie_id= tt4003440
# movie_rank= 186
# movie_title= . The House That Jack Built
# movie_runtime= 2h 32mR
# movie_year= 2018
# movie_rating= 6.8
# movie_votes= 87,742
# ===============================
#
# movie_id= tt1053960
# movie_rank= 187
# movie_title= . The Midnight Sky
# movie_runtime= 1h 58mPG-13
# movie_year= 2020
# movie_rating= 5.7
# movie_votes= 87,696
# ===============================
#
# movie_id= tt4682266
# movie_rank= 188
# movie_title= . The New Mutants
# movie_runtime= 1h 34mPG-13
# movie_year= 2020
# movie_rating= 5.3
# movie_votes= 86,953
# ===============================
#
# movie_id= tt6998518
# movie_rank= 189
# movie_title= . Mandy
# movie_runtime= 2h 1mNot Rated
# movie_year= 2018
# movie_rating= 6.5
# movie_votes= 86,665
# ===============================
#
# movie_id= tt3224458
# movie_rank= 190
# movie_title= . A Beautiful Day in the Neighborhood
# movie_runtime= 1h 49mPG
# movie_year= 2019
# movie_rating= 7.2
# movie_votes= 86,372
# ===============================
#
# movie_id= tt5688932
# movie_rank= 191
# movie_title= . Sorry to Bother You
# movie_runtime= 1h 52mR
# movie_year= 2018
# movie_rating= 6.9
# movie_votes= 86,273
# ===============================
#
# movie_id= tt6513120
# movie_rank= 192
# movie_title= . Fighting with My Family
# movie_runtime= 1h 48mPG-13
# movie_year= 2019
# movie_rating= 7.1
# movie_votes= 86,067
# ===============================
#
# movie_id= tt4560436
# movie_rank= 193
# movie_title= . Mile 22
# movie_runtime= 1h 34mR
# movie_year= 2018
# movie_rating= 6.1
# movie_votes= 85,336
# ===============================
#
# movie_id= tt8623904
# movie_rank= 194
# movie_title= . Last Christmas
# movie_runtime= 1h 43mPG-13
# movie_year= 2019
# movie_rating= 6.5
# movie_votes= 85,217
# ===============================
#
# movie_id= tt8350360
# movie_rank= 195
# movie_title= . Annabelle Comes Home
# movie_runtime= 1h 46mR
# movie_year= 2019
# movie_rating= 5.9
# movie_votes= 84,735
# ===============================
#
# movie_id= tt8695030
# movie_rank= 196
# movie_title= . The Dead Don't Die
# movie_runtime= 1h 44mR
# movie_year= 2019
# movie_rating= 5.5
# movie_votes= 83,890
# ===============================
#
# movie_id= tt2531344
# movie_rank= 197
# movie_title= . Blockers
# movie_runtime= 1h 42mR
# movie_year= 2018
# movie_rating= 6.2
# movie_votes= 83,588
# ===============================
#
# movie_id= tt3387520
# movie_rank= 198
# movie_title= . Scary Stories to Tell in the Dark
# movie_runtime= 1h 48mPG-13
# movie_year= 2019
# movie_rating= 6.2
# movie_votes= 83,574
# ===============================
#
# movie_id= tt8075192
# movie_rank= 199
# movie_title= . Shoplifters
# movie_runtime= 2h 1mR
# movie_year= 2018
# movie_rating= 7.9
# movie_votes= 83,522
# ===============================
#
# movie_id= tt8155288
# movie_rank= 200
# movie_title= . Happy Death Day 2U
# movie_runtime= 1h 40mPG-13
# movie_year= 2019
# movie_rating= 6.2
# movie_votes= 83,172
# ===============================
#
# movie_id= tt1634106
# movie_rank= 201
# movie_title= . Bloodshot
# movie_runtime= 1h 49mPG-13
# movie_year= 2020
# movie_rating= 5.7
# movie_votes= 83,011
# ===============================
#
# movie_id= tt4575576
# movie_rank= 202
# movie_title= . Christopher Robin
# movie_runtime= 1h 44mPG
# movie_year= 2018
# movie_rating= 7.2
# movie_votes= 82,777
# ===============================
#
# movie_id= tt5220122
# movie_rank= 203
# movie_title= . Hotel Transylvania 3: Summer Vacation
# movie_runtime= 1h 37mPG
# movie_year= 2018
# movie_rating= 6.3
# movie_votes= 82,427
# ===============================
#
# movie_id= tt6663582
# movie_rank= 204
# movie_title= . The Spy Who Dumped Me
# movie_runtime= 1h 57mR
# movie_year= 2018
# movie_rating= 6.0
# movie_votes= 81,687
# ===============================
#
# movie_id= tt1055423
# movie_rank= 205
# movie_title= . Dara of Jasenovac
# movie_runtime= 2h 10mR
# movie_year= 2020
# movie_rating= 8.1
# movie_votes= 81,651
# ===============================
#
# movie_id= tt2709692
# movie_rank= 206
# movie_title= . The Grinch
# movie_runtime= 1h 25mPG
# movie_year= 2018
# movie_rating= 6.4
# movie_votes= 81,149
# ===============================
#
# movie_id= tt6921996
# movie_rank= 207
# movie_title= . Johnny English Strikes Again
# movie_runtime= 1h 29mPG
# movie_year= 2018
# movie_rating= 6.2
# movie_votes= 81,141
# ===============================
#
# movie_id= tt3861390
# movie_rank= 208
# movie_title= . Dumbo
# movie_runtime= 1h 52mPG
# movie_year= 2019
# movie_rating= 6.3
# movie_votes= 81,048
# ===============================
#
# movie_id= tt7014006
# movie_rank= 209
# movie_title= . Eighth Grade
# movie_runtime= 1h 33mR
# movie_year= 2018
# movie_rating= 7.4
# movie_votes= 81,031
# ===============================
#
# movie_id= tt1061828
# movie_rank= 210
# movie_title= . Mank
# movie_runtime= 2h 11mR
# movie_year= 2020
# movie_rating= 6.8
# movie_votes= 80,817
# ===============================
#
# movie_id= tt6977338
# movie_rank= 211
# movie_title= . Good Boys
# movie_runtime= 1h 30mR
# movie_year= 2019
# movie_rating= 6.7
# movie_votes= 79,288
# ===============================
#
# movie_id= tt2990140
# movie_rank= 212
# movie_title= . The Christmas Chronicles
# movie_runtime= 1h 44mPG
# movie_year= 2018
# movie_rating= 7.0
# movie_votes= 79,274
# ===============================
#
# movie_id= tt6472976
# movie_rank= 213
# movie_title= . Five Feet Apart
# movie_runtime= 1h 56mPG-13
# movie_year= 2019
# movie_rating= 7.2
# movie_votes= 79,169
# ===============================
#
# movie_id= tt6679794
# movie_rank= 214
# movie_title= . Outlaw King
# movie_runtime= 2h 1mR
# movie_year= 2018
# movie_rating= 6.9
# movie_votes= 78,637
# ===============================
#
# movie_id= tt4532826
# movie_rank= 215
# movie_title= . Robin Hood
# movie_runtime= 1h 56mPG-13
# movie_year= 2018
# movie_rating= 5.3
# movie_votes= 78,136
# ===============================
#
# movie_id= tt5033998
# movie_rank= 216
# movie_title= . Charlie's Angels
# movie_runtime= 1h 58mPG-13
# movie_year= 2019
# movie_rating= 5.0
# movie_votes= 78,118
# ===============================
#
# movie_id= tt8359848
# movie_rank= 217
# movie_title= . Climax
# movie_runtime= 1h 37mR
# movie_year= 2018
# movie_rating= 6.9
# movie_votes= 76,678
# ===============================
#
# movie_id= tt7638348
# movie_rank= 218
# movie_title= . Boss Level
# movie_runtime= 1h 40mTV-MA
# movie_year= 2020
# movie_rating= 6.8
# movie_votes= 76,628
# ===============================
#
# movie_id= tt5719748
# movie_rank= 219
# movie_title= . Cold Pursuit
# movie_runtime= 1h 59mR
# movie_year= 2019
# movie_rating= 6.2
# movie_votes= 75,672
# ===============================
#
# movie_id= tt5613484
# movie_rank= 220
# movie_title= . Mid90s
# movie_runtime= 1h 25mR
# movie_year= 2018
# movie_rating= 7.3
# movie_votes= 75,196
# ===============================
#
# movie_id= tt1137450
# movie_rank= 221
# movie_title= . Death Wish
# movie_runtime= 1h 47mR
# movie_year= 2018
# movie_rating= 6.3
# movie_votes= 75,146
# ===============================
#
# movie_id= tt7775622
# movie_rank= 222
# movie_title= . Free Solo
# movie_runtime= 1h 40mPG-13
# movie_year= 2018
# movie_rating= 8.1
# movie_votes= 74,957
# ===============================
#
# movie_id= tt9866072
# movie_rank= 223
# movie_title= . Holidate
# movie_runtime= 1h 44mTV-MA
# movie_year= 2020
# movie_rating= 6.1
# movie_votes= 74,835
# ===============================
#
# movie_id= tt1005951
# movie_rank= 224
# movie_title= . Unhinged
# movie_runtime= 1h 30mR
# movie_year= 2020
# movie_rating= 6.0
# movie_votes= 74,804
# ===============================
#
# movie_id= tt9686708
# movie_rank= 225
# movie_title= . The King of Staten Island
# movie_runtime= 2h 16mR
# movie_year= 2020
# movie_rating= 7.1
# movie_votes= 74,799
# ===============================
#
# movie_id= tt3513498
# movie_rank= 226
# movie_title= . The Lego Movie 2: The Second Part
# movie_runtime= 1h 47mPG
# movie_year= 2019
# movie_rating= 6.6
# movie_votes= 74,579
# ===============================
#
# movie_id= tt1028027
# movie_rank= 227
# movie_title= . Coolie No. 1
# movie_runtime= 2h 14mTV-14
# movie_year= 2020
# movie_rating= 4.2
# movie_votes= 74,037
# ===============================
#
# movie_id= tt4916630
# movie_rank= 228
# movie_title= . Just Mercy
# movie_runtime= 2h 17mPG-13
# movie_year= 2019
# movie_rating= 7.6
# movie_votes= 73,725
# ===============================
#
# movie_id= tt7282468
# movie_rank= 229
# movie_title= . Burning
# movie_runtime= 2h 28mNot Rated
# movie_year= 2018
# movie_rating= 7.5
# movie_votes= 73,213
# ===============================
#
# movie_id= tt2452244
# movie_rank= 230
# movie_title= . Isn't It Romantic
# movie_runtime= 1h 29mPG-13
# movie_year= 2019
# movie_rating= 5.9
# movie_votes= 72,842
# ===============================
#
# movie_id= tt8688634
# movie_rank= 231
# movie_title= . 21 Bridges
# movie_runtime= 1h 39mR
# movie_year= 2019
# movie_rating= 6.6
# movie_votes= 72,098
# ===============================
#
# movie_id= tt4477536
# movie_rank= 232
# movie_title= . Fifty Shades Freed
# movie_runtime= 1h 45mR
# movie_year= 2018
# movie_rating= 4.5
# movie_votes= 71,733
# ===============================
#
# movie_id= tt8368406
# movie_rank= 233
# movie_title= . Vivarium
# movie_runtime= 1h 37mR
# movie_year= 2019
# movie_rating= 5.9
# movie_votes= 70,499
# ===============================
#
# movie_id= tt8291224
# movie_rank= 234
# movie_title= . Uri: The Surgical Strike
# movie_runtime= 2h 18mNot Rated
# movie_year= 2019
# movie_rating= 8.2
# movie_votes= 69,831
# ===============================
#
# movie_id= tt8368512
# movie_rank= 235
# movie_title= . The Courier
# movie_runtime= 1h 52mPG-13
# movie_year= 2020
# movie_rating= 7.2
# movie_votes= 69,774
# ===============================
#
# movie_id= tt1846589
# movie_rank= 236
# movie_title= . Hunter Killer
# movie_runtime= 2h 1mR
# movie_year= 2018
# movie_rating= 6.6
# movie_votes= 69,750
# ===============================
#
# movie_id= tt5726086
# movie_rank= 237
# movie_title= . Insidious: The Last Key
# movie_runtime= 1h 43mPG-13
# movie_year= 2018
# movie_rating= 5.7
# movie_votes= 69,681
# ===============================
#
# movie_id= tt1091938
# movie_rank= 238
# movie_title= . Freaky
# movie_runtime= 1h 42mR
# movie_year= 2020
# movie_rating= 6.3
# movie_votes= 69,593
# ===============================
#
# movie_id= tt6673612
# movie_rank= 239
# movie_title= . Dolittle
# movie_runtime= 1h 41mPG
# movie_year= 2020
# movie_rating= 5.6
# movie_votes= 69,387
# ===============================
#
# movie_id= tt6850820
# movie_rank= 240
# movie_title= . Peppermint
# movie_runtime= 1h 41mR
# movie_year= 2018
# movie_rating= 6.5
# movie_votes= 69,267
# ===============================
#
# movie_id= tt1103237
# movie_rank= 241
# movie_title= . Demon Slayer: Kimetsu no Yaiba - The Movie: Mugen Train
# movie_runtime= 1h 57mTV-14
# movie_year= 2020
# movie_rating= 8.2
# movie_votes= 69,132
# ===============================
#
# movie_id= tt4971344
# movie_rank= 242
# movie_title= . The Sisters Brothers
# movie_runtime= 2h 2mR
# movie_year= 2018
# movie_rating= 6.9
# movie_votes= 69,081
# ===============================
#
# movie_id= tt8637428
# movie_rank= 243
# movie_title= . The Farewell
# movie_runtime= 1h 40mPG
# movie_year= 2019
# movie_rating= 7.5
# movie_votes= 69,064
# ===============================
#
# movie_id= tt5461944
# movie_rank= 244
# movie_title= . Hotel Mumbai
# movie_runtime= 2h 3mR
# movie_year= 2018
# movie_rating= 7.6
# movie_votes= 68,916
# ===============================
#
# movie_id= tt6133466
# movie_rank= 245
# movie_title= . The First Purge
# movie_runtime= 1h 37mR
# movie_year= 2018
# movie_rating= 5.2
# movie_votes= 68,852
# ===============================
#
# movie_id= tt6902676
# movie_rank= 246
# movie_title= . Guns Akimbo
# movie_runtime= 1h 38mR
# movie_year= 2019
# movie_rating= 6.3
# movie_votes= 67,543
# ===============================
#
# movie_id= tt5113040
# movie_rank= 247
# movie_title= . The Secret Life of Pets 2
# movie_runtime= 1h 26mPG
# movie_year= 2019
# movie_rating= 6.4
# movie_votes= 67,170
# ===============================
#
# movie_id= tt6475714
# movie_rank= 248
# movie_title= . Monster Hunter
# movie_runtime= 1h 43mPG-13
# movie_year= 2020
# movie_rating= 5.2
# movie_votes= 66,086
# ===============================
#
# movie_id= tt4244998
# movie_rank= 249
# movie_title= . Alpha
# movie_runtime= 1h 36mPG-13
# movie_year= 2018
# movie_rating= 6.6
# movie_votes= 65,417
# ===============================
#
# movie_id= tt7043012
# movie_rank= 250
# movie_title= . Velvet Buzzsaw
# movie_runtime= 1h 53mR
# movie_year= 2019
# movie_rating= 5.7
# movie_votes= 64,949
# ===============================
#
# movie_id= tt2388771
# movie_rank= 251
# movie_title= . Mowgli: Legend of the Jungle
# movie_runtime= 1h 44mPG-13
# movie_year= 2018
# movie_rating= 6.5
# movie_votes= 64,861
# ===============================
#
# movie_id= tt9731534
# movie_rank= 252
# movie_title= . The Night House
# movie_runtime= 1h 47mR
# movie_year= 2020
# movie_rating= 6.5
# movie_votes= 64,250
# ===============================
#
# movie_id= tt1298644
# movie_rank= 253
# movie_title= . The Hustle
# movie_runtime= 1h 33mPG-13
# movie_year= 2019
# movie_rating= 5.4
# movie_votes= 64,093
# ===============================
#
# movie_id= tt8526872
# movie_rank= 254
# movie_title= . Dolemite Is My Name
# movie_runtime= 1h 58mR
# movie_year= 2019
# movie_rating= 7.2
# movie_votes= 63,881
# ===============================
#
# movie_id= tt3892172
# movie_rank= 255
# movie_title= . Leave No Trace
# movie_runtime= 1h 49mPG
# movie_year= 2018
# movie_rating= 7.1
# movie_votes= 63,841
# ===============================
#
# movie_id= tt6079516
# movie_rank= 256
# movie_title= . I See You
# movie_runtime= 1h 38mR
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 63,392
# ===============================
#
# movie_id= tt4126476
# movie_rank= 257
# movie_title= . After
# movie_runtime= 1h 45mPG-13
# movie_year= 2019
# movie_rating= 5.3
# movie_votes= 63,006
# ===============================
#
# movie_id= tt6742252
# movie_rank= 258
# movie_title= . The Guilty
# movie_runtime= 1h 25mR
# movie_year= 2018
# movie_rating= 7.5
# movie_votes= 62,985
# ===============================
#
# movie_id= tt4687108
# movie_rank= 259
# movie_title= . In the Tall Grass
# movie_runtime= 1h 41mTV-MA
# movie_year= 2019
# movie_rating= 5.5
# movie_votes= 62,841
# ===============================
#
# movie_id= tt6908274
# movie_rank= 260
# movie_title= . Mirage
# movie_runtime= 2h 8mTV-MA
# movie_year= 2018
# movie_rating= 7.4
# movie_votes= 62,239
# ===============================
#
# movie_id= tt5610554
# movie_rank= 261
# movie_title= . Tully
# movie_runtime= 1h 35mR
# movie_year= 2018
# movie_rating= 6.9
# movie_votes= 62,191
# ===============================
#
# movie_id= tt8291806
# movie_rank= 262
# movie_title= . Pain and Glory
# movie_runtime= 1h 53mR
# movie_year= 2019
# movie_rating= 7.5
# movie_votes= 62,009
# ===============================
#
# movie_id= tt0385887
# movie_rank= 263
# movie_title= . Motherless Brooklyn
# movie_runtime= 2h 24mR
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 61,651
# ===============================
#
# movie_id= tt6772950
# movie_rank= 264
# movie_title= . Truth or Dare
# movie_runtime= 1h 40mPG-13
# movie_year= 2018
# movie_rating= 5.2
# movie_votes= 61,614
# ===============================
#
# movie_id= tt6398184
# movie_rank= 265
# movie_title= . Downton Abbey
# movie_runtime= 2h 2mPG
# movie_year= 2019
# movie_rating= 7.4
# movie_votes= 61,360
# ===============================
#
# movie_id= tt7374948
# movie_rank= 266
# movie_title= . Always Be My Maybe
# movie_runtime= 1h 41mPG-13
# movie_year= 2019
# movie_rating= 6.8
# movie_votes= 61,279
# ===============================
#
# movie_id= tt1288846
# movie_rank= 267
# movie_title= . My Octopus Teacher
# movie_runtime= 1h 25mTV-G
# movie_year= 2020
# movie_rating= 8.1
# movie_votes= 61,141
# ===============================
#
# ...
#   'movie_rating': '5.6',
#   'movie_votes': '36,054'},
#  {'movie_id': 'tt1032414',
#   'movie_rank': '420',
#   'movie_title': '. Article 15',
#   'movie_runtime': '2h 10mNot Rated',
#   'movie_year': '2019',
#   'movie_rating': '8.1',
#   'movie_votes': '35,992'},
#  {'movie_id': 'tt6865690',
#   'movie_rank': '421',
#   'movie_title': '. The Professor',
#   'movie_runtime': '1h 30mR',
#   'movie_year': '2018',
#   'movie_rating': '6.7',
#   'movie_votes': '35,943'},
#  {'movie_id': 'tt9398640',
#   'movie_rank': '422',
#   'movie_title': '. Between Two Ferns: The Movie',
#   'movie_runtime': '1h 22mTV-MA',
#   'movie_year': '2019',
#   'movie_rating': '6.1',
#   'movie_votes': '35,911'},
#  {'movie_id': 'tt3256226',
#   'movie_rank': '423',
#   'movie_title': '. IO',
#   'movie_runtime': '1h 36mTV-14',
#   'movie_year': '2019',
#   'movie_rating': '4.8',
#   'movie_votes': '35,891'},
#  {'movie_id': 'tt5935704',
#   'movie_rank': '424',
#   'movie_title': '. Padmaavat',
#   'movie_runtime': '2h 43mNot Rated',
#   'movie_year': '2018',
#   'movie_rating': '7.0',
#   'movie_votes': '35,759'},
#  {'movie_id': 'tt2076298',
#   'movie_rank': '425',
#   'movie_title': '. Ip Man 4: The Finale',
#   'movie_runtime': '1h 47mNot Rated',
#   'movie_year': '2019',
#   'movie_rating': '7.0',
#   'movie_votes': '35,754'},
#  {'movie_id': 'tt9806192',
#   'movie_rank': '426',
#   'movie_title': '. I Lost My Body',
#   'movie_runtime': '1h 21m16+',
#   'movie_year': '2019',
#   'movie_rating': '7.5',
#   'movie_votes': '35,745'},
#  {'movie_id': 'tt8108268',
#   'movie_rank': '427',
#   'movie_title': '. The Tashkent Files',
#   'movie_runtime': '2h 14mNot Rated',
#   'movie_year': '2019',
#   'movie_rating': '8.1',
#   'movie_votes': '35,668'},
#  {'movie_id': 'tt1052109',
#   'movie_rank': '428',
#   'movie_title': '. The Forgotten Battle',
#   'movie_runtime': '2h 4mTV-MA',
#   'movie_year': '2020',
#   'movie_rating': '7.1',
#   'movie_votes': '35,653'},
#  {'movie_id': 'tt8108274',
#   'movie_rank': '429',
#   'movie_title': '. Tanhaji: The Unsung Warrior',
#   'movie_runtime': '2h 15mNot Rated',
#   'movie_year': '2020',
#   'movie_rating': '7.5',
#   'movie_votes': '35,498'},
#  {'movie_id': 'tt7485048',
#   'movie_rank': '430',
#   'movie_title': '. Super 30',
#   'movie_runtime': '2h 34mNot Rated',
#   'movie_year': '2019',
#   'movie_rating': '7.9',
#   'movie_votes': '35,412'},
#  {'movie_id': 'tt1035062',
#   'movie_rank': '431',
#   'movie_title': '. Gunjan Saxena: The Kargil Girl',
#   'movie_runtime': '1h 52mTV-14',
#   'movie_year': '2020',
#   'movie_rating': '5.5',
#   'movie_votes': '35,359'},
#  {'movie_id': 'tt4073790',
#   'movie_rank': '432',
#   'movie_title': '. The Darkest Minds',
#   'movie_runtime': '1h 44mPG-13',
#   'movie_year': '2018',
#   'movie_rating': '5.7',
#   'movie_votes': '35,323'},
#  {'movie_id': 'tt9606374',
#   'movie_rank': '433',
#   'movie_title': '. On the Rocks',
#   'movie_runtime': '1h 36mR',
#   'movie_year': '2020',
#   'movie_rating': '6.4',
#   'movie_votes': '35,271'},
#  {'movie_id': 'tt8361028',
#   'movie_rank': '434',
#   'movie_title': '. Cam',
#   'movie_runtime': '1h 34mTV-MA',
#   'movie_year': '2018',
#   'movie_rating': '5.9',
#   'movie_votes': '35,261'},
#  {'movie_id': 'tt7605074',
#   'movie_rank': '435',
#   'movie_title': '. The Wandering Earth',
#   'movie_runtime': '2h 5m13+',
#   'movie_year': '2019',
#   'movie_rating': '5.9',
#   'movie_votes': '35,189'},
#  {'movie_id': 'tt6802308',
#   'movie_rank': '436',
#   'movie_title': '. The 15:17 to Paris',
#   'movie_runtime': '1h 34mPG-13',
#   'movie_year': '2018',
#   'movie_rating': '5.3',
#   'movie_votes': '35,148'},
#  {'movie_id': 'tt7019842',
#   'movie_rank': '437',
#   'movie_title': '. 96',
#   'movie_runtime': '2h 38mNot Rated',
#   'movie_year': '2018',
#   'movie_rating': '8.5',
#   'movie_votes': '34,980'},
#  {'movie_id': 'tt4799066',
#   'movie_rank': '438',
#   'movie_title': '. Midnight Sun',
#   'movie_runtime': '1h 31mPG-13',
#   'movie_year': '2018',
#   'movie_rating': '6.6',
#   'movie_votes': '34,947'},
#  {'movie_id': 'tt6535880',
#   'movie_rank': '439',
#   'movie_title': '. Haunt',
#   'movie_runtime': '1h 32mR',
#   'movie_year': '2019',
#   'movie_rating': '6.3',
#   'movie_votes': '34,710'},
#  {'movie_id': 'tt6513656',
#   'movie_rank': '440',
#   'movie_title': '. Escape Plan 2: Hades',
#   'movie_runtime': '1h 36mR',
#   'movie_year': '2018',
#   'movie_rating': '3.9',
#   'movie_votes': '34,404'},
#  {'movie_id': 'tt4068576',
#   'movie_rank': '441',
#   'movie_title': '. The Nightingale',
#   'movie_runtime': '2h 16mR',
#   'movie_year': '2018',
#   'movie_rating': '7.3',
#   'movie_votes': '34,343'},
#  {'movie_id': 'tt8722346',
#   'movie_rank': '442',
#   'movie_title': '. Queen & Slim',
#   'movie_runtime': '2h 12mR',
#   'movie_year': '2019',
#   'movie_rating': '7.1',
#   'movie_votes': '34,034'},
#  {'movie_id': 'tt1198989',
#   'movie_rank': '443',
#   'movie_title': '. David Attenborough: A Life on Our Planet',
#   'movie_runtime': '1h 23mPG',
#   'movie_year': '2020',
#   'movie_rating': '8.9',
#   'movie_votes': '33,942'},
#  {'movie_id': 'tt4357394',
#   'movie_rank': '444',
#   'movie_title': '. Tau',
#   'movie_runtime': '1h 37mR',
#   'movie_year': '2018',
#   'movie_rating': '5.8',
#   'movie_votes': '33,897'},
#  {'movie_id': 'tt9340860',
#   'movie_rank': '445',
#   'movie_title': '. Let Him Go',
#   'movie_runtime': '1h 53mR',
#   'movie_year': '2020',
#   'movie_rating': '6.7',
#   'movie_votes': '33,889'},
#  {'movie_id': 'tt6095472',
#   'movie_rank': '446',
#   'movie_title': '. The Angry Birds Movie 2',
#   'movie_runtime': '1h 37mPG',
#   'movie_year': '2019',
#   'movie_rating': '6.4',
#   'movie_votes': '33,775'},
#  {'movie_id': 'tt1061292',
#   'movie_rank': '447',
#   'movie_title': '. One Night in Miami...',
#   'movie_runtime': '1h 54mR',
#   'movie_year': '2020',
#   'movie_rating': '7.1',
#   'movie_votes': '33,744'},
#  {'movie_id': 'tt1105764',
#   'movie_rank': '448',
#   'movie_title': '. The Christmas Chronicles: Part Two',
#   'movie_runtime': '1h 52mPG',
#   'movie_year': '2020',
#   'movie_rating': '6.0',
#   'movie_votes': '33,694'},
#  {'movie_id': 'tt8242084',
#   'movie_rank': '449',
#   'movie_title': '. My Spy',
#   'movie_runtime': '1h 39mPG-13',
#   'movie_year': '2020',
#   'movie_rating': '6.3',
#   'movie_votes': '33,640'},
#  {'movie_id': 'tt1285009',
#   'movie_rank': '450',
#   'movie_title': '. The Strangers: Prey at Night',
#   'movie_runtime': '1h 25mR',
#   'movie_year': '2018',
#   'movie_rating': '5.2',
#   'movie_votes': '33,619'},
#  {'movie_id': 'tt6285944',
#   'movie_rank': '451',
#   'movie_title': '. The Banker',
#   'movie_runtime': '2hPG-13',
#   'movie_year': '2020',
#   'movie_rating': '7.3',
#   'movie_votes': '33,612'},
#  {'movie_id': 'tt7547410',
#   'movie_rank': '452',
#   'movie_title': '. Dora and the Lost City of Gold',
#   'movie_runtime': '1h 42mPG',
#   'movie_year': '2019',
#   'movie_rating': '6.1',
#   'movie_votes': '33,585'},
#  {'movie_id': 'tt5501104',
#   'movie_rank': '453',
#   'movie_title': '. Border',
#   'movie_runtime': '1h 50mR',
#   'movie_year': '2018',
#   'movie_rating': '7.0',
#   'movie_votes': '33,411'},
#  {'movie_id': 'tt9086228',
#   'movie_rank': '454',
#   'movie_title': '. Gretel & Hansel',
#   'movie_runtime': '1h 27mPG-13',
#   'movie_year': '2020',
#   'movie_rating': '5.5',
#   'movie_votes': '33,221'},
#  {'movie_id': 'tt7098658',
#   'movie_rank': '455',
#   'movie_title': '. Raazi',
#   'movie_runtime': '2h 18mNot Rated',
#   'movie_year': '2018',
#   'movie_rating': '7.7',
#   'movie_votes': '33,133'},
#  {'movie_id': 'tt4986098',
#   'movie_rank': '456',
#   'movie_title': '. The Titan',
#   'movie_runtime': '1h 37mTV-MA',
#   'movie_year': '2018',
#   'movie_rating': '4.8',
#   'movie_votes': '33,014'},
#  {'movie_id': 'tt7946422',
#   'movie_rank': '457',
#   'movie_title': '. Prospect',
#   'movie_runtime': '1h 40mR',
#   'movie_year': '2018',
#   'movie_rating': '6.3',
#   'movie_votes': '32,910'},
#  {'movie_id': 'tt6269368',
#   'movie_rank': '458',
#   'movie_title': '. The Clovehitch Killer',
#   'movie_runtime': '1h 49mUnrated',
#   'movie_year': '2018',
#   'movie_rating': '6.5',
#   'movie_votes': '32,724'},
#  {'movie_id': 'tt3317234',
#   'movie_rank': '459',
#   'movie_title': '. Game Over, Man!',
#   'movie_runtime': '1h 41mTV-MA',
#   'movie_year': '2018',
#   'movie_rating': '5.4',
#   'movie_votes': '32,640'},
#  {'movie_id': 'tt9477520',
#   'movie_rank': '460',
#   'movie_title': '. Asuran',
#   'movie_runtime': '2h 21mNot Rated',
#   'movie_year': '2019',
#   'movie_rating': '8.4',
#   'movie_votes': '32,475'},
#  {'movie_id': 'tt6987770',
#   'movie_rank': '461',
#   'movie_title': '. Destination Wedding',
#   'movie_runtime': '1h 27mR',
#   'movie_year': '2018',
#   'movie_rating': '6.0',
#   'movie_votes': '32,400'},
#  {'movie_id': 'tt6218358',
#   'movie_rank': '462',
#   'movie_title': '. Calibre',
#   'movie_runtime': '1h 41mTV-MA',
#   'movie_year': '2018',
#   'movie_rating': '6.8',
#   'movie_votes': '32,359'},
#  {'movie_id': 'tt9196192',
#   'movie_rank': '463',
#   'movie_title': '. Cuties',
#   'movie_runtime': '1h 36mTV-MA',
#   'movie_year': '2020',
#   'movie_rating': '3.6',
#   'movie_votes': '32,353'},
#  {'movie_id': 'tt7242142',
#   'movie_rank': '464',
#   'movie_title': '. Blindspotting',
#   'movie_runtime': '1h 35mR',
#   'movie_year': '2018',
#   'movie_rating': '7.4',
#   'movie_votes': '32,333'},
#  {'movie_id': 'tt7721800',
#   'movie_rank': '465',
#   'movie_title': '. Bharat',
#   'movie_runtime': '2h 30mNot Rated',
#   'movie_year': '2019',
#   'movie_rating': '4.7',
#   'movie_votes': '32,076'},
#  {'movie_id': 'tt4995776',
#   'movie_rank': '466',
#   'movie_title': '. The Red Sea Diving Resort',
#   'movie_runtime': '2h 9mTV-MA',
#   'movie_year': '2019',
#   'movie_rating': '6.6',
#   'movie_votes': '31,786'},
#  {'movie_id': 'tt3721964',
#   'movie_rank': '467',
#   'movie_title': '. Gringo',
#   'movie_runtime': '1h 51mR',
#   'movie_year': '2018',
#   'movie_rating': '6.1',
#   'movie_votes': '31,711'},
#  {'movie_id': 'tt6436726',
#   'movie_rank': '468',
#   'movie_title': '. 7500',
#   'movie_runtime': '1h 33mR',
#   'movie_year': '2019',
#   'movie_rating': '6.3',
#   'movie_votes': '31,700'},
#  {'movie_id': 'tt6857166',
#   'movie_rank': '469',
#   'movie_title': '. Book Club',
#   'movie_runtime': '1h 44mPG-13',
#   'movie_year': '2018',
#   'movie_rating': '6.1',
#   'movie_votes': '31,661'},
#  {'movie_id': 'tt1298789',
#   'movie_rank': '470',
#   'movie_title': '. American Murder: The Family Next Door',
#   'movie_runtime': '1h 23mTV-MA',
#   'movie_year': '2020',
#   'movie_rating': '7.2',
#   'movie_votes': '31,528'},
#  {'movie_id': 'tt5144174',
#   'movie_rank': '471',
#   'movie_title': '. The Dry',
#   'movie_runtime': '1h 57mR',
#   'movie_year': '2020',
#   'movie_rating': '6.8',
#   'movie_votes': '31,257'},
#  {'movie_id': 'tt7137380',
#   'movie_rank': '472',
#   'movie_title': '. Destroyer',
#   'movie_runtime': '2h 1mR',
#   'movie_year': '2018',
#   'movie_rating': '6.2',
#   'movie_votes': '31,227'},
#  {'movie_id': 'tt7430722',
#   'movie_rank': '473',
#   'movie_title': '. War',
#   'movie_runtime': '2h 31mNot Rated',
#   'movie_year': '2019',
#   'movie_rating': '6.5',
#   'movie_votes': '31,139'},
#  {'movie_id': 'tt9354944',
#   'movie_rank': '474',
#   'movie_title': '. Jexi',
#   'movie_runtime': '1h 24mR',
#   'movie_year': '2019',
#   'movie_rating': '6.0',
#   'movie_votes': '30,869'},
#  {'movie_id': 'tt5929754',
#   'movie_rank': '475',
#   'movie_title': '. Wildlife',
#   'movie_runtime': '1h 45mPG-13',
#   'movie_year': '2018',
#   'movie_rating': '6.8',
#   'movie_votes': '30,761'},
#  {'movie_id': 'tt9573980',
#   'movie_rank': '476',
#   'movie_title': '. Leaving Neverland',
#   'movie_runtime': '4hTV-MA',
#   'movie_year': '2019',
#   'movie_rating': '7.0',
#   'movie_votes': '30,740'},
#  {'movie_id': 'tt7634968',
#   'movie_rank': '477',
#   'movie_title': '. What Men Want',
#   'movie_runtime': '1h 57mR',
#   'movie_year': '2019',
#   'movie_rating': '5.4',
#   'movie_votes': '30,708'},
#  {'movie_id': 'tt7961060',
#   'movie_rank': '478',
#   'movie_title': '. Dragon Ball Super: Broly',
#   'movie_runtime': '1h 40mPG',
#   'movie_year': '2018',
#   'movie_rating': '7.7',
#   'movie_votes': '30,619'},
#  {'movie_id': 'tt7772582',
#   'movie_rank': '479',
#   'movie_title': '. Never Rarely Sometimes Always',
#   'movie_runtime': '1h 41mPG-13',
#   'movie_year': '2020',
#   'movie_rating': '7.4',
#   'movie_votes': '30,506'},
#  {'movie_id': 'tt8954732',
#   'movie_rank': '480',
#   'movie_title': '. The Princess Switch',
#   'movie_runtime': '1h 41mTV-PG',
#   'movie_year': '2018',
#   'movie_rating': '6.1',
#   'movie_votes': '30,300'},
#  {'movie_id': 'tt8130968',
#   'movie_rank': '481',
#   'movie_title': '. Badla',
#   'movie_runtime': '1h 58mNot Rated',
#   'movie_year': '2019',
#   'movie_rating': '7.8',
#   'movie_votes': '30,204'},
#  {'movie_id': 'tt1131714',
#   'movie_rank': '482',
#   'movie_title': '. Shiva Baby',
#   'movie_runtime': '1h 17mNot Rated',
#   'movie_year': '2020',
#   'movie_rating': '7.1',
#   'movie_votes': '30,110'},
#  {'movie_id': 'tt7329656',
#   'movie_rank': '483',
#   'movie_title': '. 47 Meters Down: Uncaged',
#   'movie_runtime': '1h 30mPG-13',
#   'movie_year': '2019',
#   'movie_rating': '5.0',
#   'movie_votes': '30,069'},
#  {'movie_id': 'tt3089630',
#   'movie_rank': '484',
#   'movie_title': '. Artemis Fowl',
#   'movie_runtime': '1h 35mPG',
#   'movie_year': '2020',
#   'movie_rating': '4.3',
#   'movie_votes': '30,045'},
#  {'movie_id': 'tt2762506',
#   'movie_rank': '485',
#   'movie_title': '. Bacurau',
#   'movie_runtime': '2h 11mNot Rated',
#   'movie_year': '2019',
#   'movie_rating': '7.3',
#   'movie_votes': '29,959'},
#  {'movie_id': 'tt7149730',
#   'movie_rank': '486',
#   'movie_title': '. The Silencing',
#   'movie_runtime': '1h 33mR',
#   'movie_year': '2020',
#   'movie_rating': '6.2',
#   'movie_votes': '29,926'},
#  {'movie_id': 'tt1308728',
#   'movie_rank': '487',
#   'movie_title': '. The Happytime Murders',
#   'movie_runtime': '1h 31mR',
#   'movie_year': '2018',
#   'movie_rating': '5.5',
#   'movie_votes': '29,906'},
#  {'movie_id': 'tt4648786',
#   'movie_rank': '488',
#   'movie_title': '. Harriet',
#   'movie_runtime': '2h 5mPG-13',
#   'movie_year': '2019',
#   'movie_rating': '6.7',
#   'movie_votes': '29,801'},
#  {'movie_id': 'tt9691136',
#   'movie_rank': '489',
#   'movie_title': '. Shadow in the Cloud',
#   'movie_runtime': '1h 23mR',
#   'movie_year': '2020',
#   'movie_rating': '5.0',
#   'movie_votes': '29,775'},
#  {'movie_id': 'tt6288124',
#   'movie_rank': '490',
#   'movie_title': ". Don't Worry, He Won't Get Far on Foot",
#   'movie_runtime': '1h 54mR',
#   'movie_year': '2018',
#   'movie_rating': '6.8',
#   'movie_votes': '29,685'},
#  {'movie_id': 'tt2126357',
#   'movie_rank': '491',
#   'movie_title': '. Second Act',
#   'movie_runtime': '1h 43mPG-13',
#   'movie_year': '2018',
#   'movie_rating': '5.8',
#   'movie_votes': '29,655'},
#  {'movie_id': 'tt6527426',
#   'movie_rank': '492',
#   'movie_title': '. Zero',
#   'movie_runtime': '2h 44mNot Rated',
#   'movie_year': '2018',
#   'movie_rating': '5.2',
#   'movie_votes': '29,653'},
#  {'movie_id': 'tt9252468',
#   'movie_rank': '493',
#   'movie_title': '. Mosul',
#   'movie_runtime': '1h 41mTV-MA',
#   'movie_year': '2019',
#   'movie_rating': '7.1',
#   'movie_votes': '29,652'},
#  {'movie_id': 'tt1138238',
#   'movie_rank': '494',
#   'movie_title': '. The Dissident',
#   'movie_runtime': '1h 59mPG-13',
#   'movie_year': '2020',
#   'movie_rating': '7.8',
#   'movie_votes': '29,583'},
#  {'movie_id': 'tt3152592',
#   'movie_rank': '495',
#   'movie_title': '. Scoob!',
#   'movie_runtime': '1h 33mPG',
#   'movie_year': '2020',
#   'movie_rating': '5.6',
#   'movie_votes': '29,336'},
#  {'movie_id': 'tt9072352',
#   'movie_rank': '496',
#   'movie_title': '. Relic',
#   'movie_runtime': '1h 29mR',
#   'movie_year': '2020',
#   'movie_rating': '6.0',
#   'movie_votes': '29,282'},
#  {'movie_id': 'tt1006569',
#   'movie_rank': '497',
#   'movie_title': '. Antebellum',
#   'movie_runtime': '1h 45mR',
#   'movie_year': '2020',
#   'movie_rating': '5.8',
#   'movie_votes': '29,199'},
#  {'movie_id': 'tt8652728',
#   'movie_rank': '498',
#   'movie_title': '. Waves',
#   'movie_runtime': '2h 15mR',
#   'movie_year': '2019',
#   'movie_rating': '7.5',
#   'movie_votes': '29,103'},
#  {'movie_id': 'tt7748244',
#   'movie_rank': '499',
#   'movie_title': '. Mortal World',
#   'movie_runtime': '1h 47m',
#   'movie_year': '2018',
#   'movie_rating': '7.6',
#   'movie_votes': '29,052'},
#  {'movie_id': 'tt6768578',
#   'movie_rank': '500',
#   'movie_title': '. Dogman',
#   'movie_runtime': '1h 43mNot Rated',
#   'movie_year': '2018',
#   'movie_rating': '7.2',
#   'movie_votes': '28,823'}]

# %%
# To convert the movies list of dics to dataframe
df_movies = pd.DataFrame(Movies_list)
df_movies
# Out:
#       movie_id movie_rank             movie_title    movie_runtime movie_year  \
# 0    tt7286456          1                   Joker           2h 2mR       2019
# 1    tt4154796          2       Avengers: Endgame       3h 1mPG-13       2019
# 2    tt4154756          3  Avengers: Infinity War      2h 29mPG-13       2018
# 3    tt6751668          4                Parasite          2h 12mR       2019
# 4    tt1825683          5           Black Panther      2h 14mPG-13       2018
# ..         ...        ...                     ...              ...        ...
# 495  tt9072352        496                 . Relic          1h 29mR       2020
# 496  tt1006569        497            . Antebellum          1h 45mR       2020
# 497  tt8652728        498                 . Waves          2h 15mR       2019
# 498  tt7748244        499          . Mortal World           1h 47m       2018
# 499  tt6768578        500                . Dogman  1h 43mNot Rated       2018
#
#     movie_rating movie_votes
# 0            8.4   1,422,218
# 1            8.4   1,227,564
# 2            8.4   1,167,536
# 3            8.5     903,939
# 4            7.3     820,837
# ..           ...         ...
# 495          6.0      29,282
# 496          5.8      29,199
# 497          7.5      29,103
# 498          7.6      29,052
# 499          7.2      28,823
#
# [500 rows x 7 columns]

# %% [markdown]
# ***
# #  To export the colleted movies to IMDb_TopVoted.csv file.

# %%
df_movies.to_csv('IMDb_TopVoted.csv', index = False)

# %% [markdown]
# # Importing the given dataset "Movies.csv" to Pandas DataFrame called df1

# %%
# Importing the csv file to df1 and print the df1.

df1 = pd.read_csv ('Movies.csv')
df1.head()
# Out:
#     movie_id           originalTitle  \
# 0  tt7286456                   Joker
# 1  tt4154796       Avengers: Endgame
# 2  tt4154756  Avengers: Infinity War
# 3  tt6751668                Parasite
# 4  tt1825683           Black Panther
#
#                                          description ratingCategory  \
# 0  During the 1980s, a failed stand-up comedian i...              R
# 1  After the devastating events of Avengers: Infi...          PG-13
# 2  The Avengers and their allies must be willing ...          PG-13
# 3  Greed and class discrimination threaten the ne...              R
# 4  T'Challa, heir to the hidden but advanced king...          PG-13
#
#                     genres
# 0     Crime,Drama,Thriller
# 1   Action,Adventure,Drama
# 2  Action,Adventure,Sci-Fi
# 3           Drama,Thriller
# 4  Action,Adventure,Sci-Fi

# %%
# Getting the datatype info of df1
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        500 non-null    object
#  1   originalTitle   500 non-null    object
#  2   description     500 non-null    object
#  3   ratingCategory  497 non-null    object
#  4   genres          500 non-null    object
# dtypes: object(5)
# memory usage: 19.7+ KB

# %% [markdown]
# # Import the scraped data from the IMDb_TopVoted.csv file to Pandas DataFrame called df2

# %%
# You need to import the collected dataset "IMDb_TopVoted.csv" and print the df2.
# To handel Latin characters that may contained in the csv file
# with no issue, use  encoding= "ISO-8859-1" with the pd.read_csv()
# Example: df1 = pd.read_csv('thefilename.csv', encoding= "ISO-8859-1") 
# Using encoding= "ISO-8859-1" will avoid Unicode-Decode-Errors.


# You need to import the collected dataset "IMDb_TopVoted.csv" and print the df2.
df2 = pd.read_csv ('IMDb_TopVoted.csv',encoding= "ISO-8859-1")
df2.head()
# Out:
#     movie_id  movie_rank             movie_title movie_runtime  movie_year  \
# 0  tt7286456           1                   Joker        2h 2mR        2019
# 1  tt4154796           2       Avengers: Endgame    3h 1mPG-13        2019
# 2  tt4154756           3  Avengers: Infinity War   2h 29mPG-13        2018
# 3  tt6751668           4                Parasite       2h 12mR        2019
# 4  tt1825683           5           Black Panther   2h 14mPG-13        2018
#
#    movie_rating movie_votes
# 0           8.4   1,422,218
# 1           8.4   1,227,564
# 2           8.4   1,167,536
# 3           8.5     903,939
# 4           7.3     820,837

# %% [markdown]
# # Data cleansing and transformation for df2.

# %%
# Getting the datatype info of df2
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       500 non-null    object
#  1   movie_rank     500 non-null    int64
#  2   movie_title    500 non-null    object
#  3   movie_runtime  500 non-null    object
#  4   movie_year     500 non-null    int64
#  5   movie_rating   500 non-null    float64
#  6   movie_votes    500 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 27.5+ KB

# %%
# Cleaning and transforming df2
# rank, year, and votes should have a numeric integer data type.
# removing the comma from votes, so that we can change data type without getting any null values  
# Also removing the "." from the movie title that is in the beginning of some of the titles  

df2['movie_votes'] = pd.to_numeric(df2['movie_votes'].str.replace(',', ''), errors='coerce').astype('Int64')
df2["movie_votes"].dtypes
df2['movie_title'] = df2['movie_title'].str.replace('.', '')

# %%
df2.head()
# Out:
#     movie_id  movie_rank             movie_title movie_runtime  movie_year  \
# 0  tt7286456           1                   Joker        2h 2mR        2019
# 1  tt4154796           2       Avengers: Endgame    3h 1mPG-13        2019
# 2  tt4154756           3  Avengers: Infinity War   2h 29mPG-13        2018
# 3  tt6751668           4                Parasite       2h 12mR        2019
# 4  tt1825683           5           Black Panther   2h 14mPG-13        2018
#
#    movie_rating  movie_votes
# 0           8.4      1422218
# 1           8.4      1227564
# 2           8.4      1167536
# 3           8.5       903939
# 4           7.3       820837

# %%
## rank, year and votes converted to int
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       500 non-null    object
#  1   movie_rank     500 non-null    int64
#  2   movie_title    500 non-null    object
#  3   movie_runtime  500 non-null    object
#  4   movie_year     500 non-null    int64
#  5   movie_rating   500 non-null    float64
#  6   movie_votes    500 non-null    Int64
# dtypes: Int64(1), float64(1), int64(2), object(3)
# memory usage: 28.0+ KB

# %%
## Remove the R and PG-13,TV-MA,Not Rated from runtime
df2['movie_runtime'] = df2['movie_runtime'].str.replace(r'R', '')
df2['movie_runtime'] = df2['movie_runtime'].str.replace(r'PG-13', '')
df2['movie_runtime'] = df2['movie_runtime'].str.replace(r'TV-MA', '')
df2['movie_runtime'] = df2['movie_runtime'].str.replace(r'Not Rated', '')
df2.head()
# Out:
#     movie_id  movie_rank             movie_title movie_runtime  movie_year  \
# 0  tt7286456           1                   Joker         2h 2m        2019
# 1  tt4154796           2       Avengers: Endgame         3h 1m        2019
# 2  tt4154756           3  Avengers: Infinity War        2h 29m        2018
# 3  tt6751668           4                Parasite        2h 12m        2019
# 4  tt1825683           5           Black Panther        2h 14m        2018
#
#    movie_rating  movie_votes
# 0           8.4      1422218
# 1           8.4      1227564
# 2           8.4      1167536
# 3           8.5       903939
# 4           7.3       820837

# %%
# Cleaning and tranforming df2
# runtime column should be renamed to runtimeMinutes and the value should be in minutes, 
# for example: 2h 2m should be 122
    

# Rename 'runtime' column to 'runtimeMinutes' and convert the values to minutes
def runtime_to_minutes(movie_runtime):
    try:
        # Split the runtime into hours and minutes
        parts = movie_runtime.split()
        total_minutes = 0

        for part in parts:
            if 'h' in part:
                total_minutes += int(part[:-1]) * 60
            elif 'm' in part:
                total_minutes += int(part[:-1])

        return total_minutes
    except ValueError:
        return None

df2['runtimeMinutes'] = df2['movie_runtime'].apply(runtime_to_minutes)


# Display the cleaned and transformed DataFrame
df2.head()
# Out:
#     movie_id  movie_rank             movie_title movie_runtime  movie_year  \
# 0  tt7286456           1                   Joker         2h 2m        2019
# 1  tt4154796           2       Avengers: Endgame         3h 1m        2019
# 2  tt4154756           3  Avengers: Infinity War        2h 29m        2018
# 3  tt6751668           4                Parasite        2h 12m        2019
# 4  tt1825683           5           Black Panther        2h 14m        2018
#
#    movie_rating  movie_votes  runtimeMinutes
# 0           8.4      1422218           122.0
# 1           8.4      1227564           181.0
# 2           8.4      1167536           149.0
# 3           8.5       903939           132.0
# 4           7.3       820837           134.0

# %%
# Drop the original 'runtime' column
df2 = df2.drop(columns=['movie_runtime'])

# %%
df2.head()
# Out:
#     movie_id  movie_rank             movie_title  movie_year  movie_rating  \
# 0  tt7286456           1                   Joker        2019           8.4
# 1  tt4154796           2       Avengers: Endgame        2019           8.4
# 2  tt4154756           3  Avengers: Infinity War        2018           8.4
# 3  tt6751668           4                Parasite        2019           8.5
# 4  tt1825683           5           Black Panther        2018           7.3
#
#    movie_votes  runtimeMinutes
# 0      1422218           122.0
# 1      1227564           181.0
# 2      1167536           149.0
# 3       903939           132.0
# 4       820837           134.0

# %% [markdown]
# # 	Enrich the given dataset (df1) by merging it to the scraped data (df2).

# %%
# Merge the two dataframes to one dataframe called df.

common_column_name = 'movie_id'
df = pd.merge(df1, df2, on=common_column_name, how='inner')

# %%
df.head()
# Out:
#     movie_id           originalTitle  \
# 0  tt7286456                   Joker
# 1  tt4154796       Avengers: Endgame
# 2  tt4154756  Avengers: Infinity War
# 3  tt6751668                Parasite
# 4  tt1825683           Black Panther
#
#                                          description ratingCategory  \
# 0  During the 1980s, a failed stand-up comedian i...              R
# 1  After the devastating events of Avengers: Infi...          PG-13
# 2  The Avengers and their allies must be willing ...          PG-13
# 3  Greed and class discrimination threaten the ne...              R
# 4  T'Challa, heir to the hidden but advanced king...          PG-13
#
#                     genres  movie_rank             movie_title  movie_year  \
# 0     Crime,Drama,Thriller           1                   Joker        2019
# 1   Action,Adventure,Drama           2       Avengers: Endgame        2019
# 2  Action,Adventure,Sci-Fi           3  Avengers: Infinity War        2018
# 3           Drama,Thriller           4                Parasite        2019
# 4  Action,Adventure,Sci-Fi           5           Black Panther        2018
#
#    movie_rating  movie_votes  runtimeMinutes
# 0           8.4      1422218           122.0
# 1           8.4      1227564           181.0
# 2           8.4      1167536           149.0
# 3           8.5       903939           132.0
# 4           7.3       820837           134.0

# %% [markdown]
# # Rearrange the dataset fields to be listed in the following order:
# movie_id , rank , title ,  originalTitle ,  description ,
#           year ,  votes , rating ,  runtimeMinutes ,  ratingCategory ,  genres

# %%
# Rearrange the dataset fields.

# first Define the desired order of columns
desired_order = ['movie_id', 'movie_rank', 'movie_title', 'originalTitle', 'description', 'movie_year', 'movie_votes', 'movie_rating', 'runtimeMinutes', 'ratingCategory', 'genres']

# Reorder the columns in the DataFrame
df = df[desired_order]

# Display the rearranged DataFrame
df.head()
# Out:
#     movie_id  movie_rank             movie_title           originalTitle  \
# 0  tt7286456           1                   Joker                   Joker
# 1  tt4154796           2       Avengers: Endgame       Avengers: Endgame
# 2  tt4154756           3  Avengers: Infinity War  Avengers: Infinity War
# 3  tt6751668           4                Parasite                Parasite
# 4  tt1825683           5           Black Panther           Black Panther
#
#                                          description  movie_year  movie_votes  \
# 0  During the 1980s, a failed stand-up comedian i...        2019      1422218
# 1  After the devastating events of Avengers: Infi...        2019      1227564
# 2  The Avengers and their allies must be willing ...        2018      1167536
# 3  Greed and class discrimination threaten the ne...        2019       903939
# 4  T'Challa, heir to the hidden but advanced king...        2018       820837
#
#    movie_rating  runtimeMinutes ratingCategory                   genres
# 0           8.4           122.0              R     Crime,Drama,Thriller
# 1           8.4           181.0          PG-13   Action,Adventure,Drama
# 2           8.4           149.0          PG-13  Action,Adventure,Sci-Fi
# 3           8.5           132.0              R           Drama,Thriller
# 4           7.3           134.0          PG-13  Action,Adventure,Sci-Fi

# %% [markdown]
# # Export the enriched dataset to a CSV file:

# %%
# Use the following naming convention: 
# Project_3_PartA_Lastname.csv


df.to_csv('Project_3_PartA_Group14.csv', index = False)
